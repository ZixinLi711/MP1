# %% [markdown]
# # Google Colab setup with Google Drive folder
#
# This notebook provides the code you need to set up Google Colab to run and import files from within a Google Drive folder.
#
# This will allow you to upload assignment code to your Google Drive and then run the code on Google Colab machines (with free GPUs if needed).
#
# You will need to create a folder in your Google Drive to hold your assignments and you will need to open Colaboratory within this folder before running the set up code (check the link above to see how).

# %% [markdown]
# # Mount Google Drive
#
# This will allow the Colab machine to access Google Drive folders by mounting the drive on the machine. You will be asked to copy and paste an authentication code.

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
ls
# Out:
# gdrive/  sample_data/

# %% [markdown]
# # Change directory to allow imports
#
#
# As noted above, you should create a Google Drive folder to hold all your assignment files. You will need to add this code to the top of any python notebook you run to be able to import python files from your drive assignment folder (you should change the file path below to be your own assignment folder).

# %%
import os
os.chdir("/content/gdrive/My Drive/MP4")

# %%
ls # Check if this is your MP4 folder
# Out:
# data/     submission_netid_p1.csv  submission_zixinl4_p1.csv
# plot.png  submission_netid_p2.csv

# %% [markdown]
# # Copy data to local dir

# %%
# !rm -r /data
# !mkdir /data
# !cp data/cs-543-mp4-fall-2021-p1.zip /data/
# !unzip /data/cs-543-mp4-fall-2021-p1.zip -d /data
# !cp data/cs-543-mp4-fall-2021-p2.zip /data/
# !unzip /data/cs-543-mp4-fall-2021-p2.zip -d /data
# !mv /data/new_train/new_train/* /data/new_train
# !rmdir /data/new_train/new_train
# !mv /data/mod_test/mod_test/* /data/mod_test
# !rmdir /data/mod_test/mod_test
# !mv /data/validation/validation/* /data/validation
# !rmdir /data/validation/validation
# !mkdir /data/mod_test/dummy_class
# !mv /data/mod_test/*.jpg /data/mod_test/dummy_class
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /data/mod_test/mod_test/1033.jpg
#   inflating: /data/mod_test/mod_test/1034.jpg
#   inflating: /data/mod_test/mod_test/1035.jpg
#   inflating: /data/mod_test/mod_test/1036.jpg
#   inflating: /data/mod_test/mod_test/1037.jpg
#   inflating: /data/mod_test/mod_test/1038.jpg
#   inflating: /data/mod_test/mod_test/1039.jpg
#   inflating: /data/mod_test/mod_test/1040.jpg
#   inflating: /data/mod_test/mod_test/1041.jpg
#   inflating: /data/mod_test/mod_test/1042.jpg
#   inflating: /data/mod_test/mod_test/1043.jpg
#   inflating: /data/mod_test/mod_test/1044.jpg
#   inflating: /data/mod_test/mod_test/1045.jpg
#   inflating: /data/mod_test/mod_test/1046.jpg
#   inflating: /data/mod_test/mod_test/1047.jpg
#   inflating: /data/mod_test/mod_test/1048.jpg
#   inflating: /data/mod_test/mod_test/1049.jpg
#   inflating: /data/mod_test/mod_test/1050.jpg
#   inflating: /data/mod_test/mod_test/1051.jpg
#   inflating: /data/mod_test/mod_test/1052.jpg
#   inflating: /data/mod_test/mod_test/1053.jpg
#   inflating: /data/mod_test/mod_test/1054.jpg
#   inflating: /data/mod_test/mod_test/1055.jpg
#   inflating: /data/mod_test/mod_test/1056.jpg
#   inflating: /data/mod_test/mod_test/1057.jpg
#   inflating: /data/mod_test/mod_test/1058.jpg
#   inflating: /data/mod_test/mod_test/1059.jpg
#   inflating: /data/mod_test/mod_test/1060.jpg
#   inflating: /data/mod_test/mod_test/1061.jpg
#   inflating: /data/mod_test/mod_test/1062.jpg
#   inflating: /data/mod_test/mod_test/1063.jpg
#   inflating: /data/mod_test/mod_test/1064.jpg
#   inflating: /data/mod_test/mod_test/1065.jpg
#   inflating: /data/mod_test/mod_test/1066.jpg
#   inflating: /data/mod_test/mod_test/1067.jpg
#   inflating: /data/mod_test/mod_test/1068.jpg
#   inflating: /data/mod_test/mod_test/1069.jpg
#   inflating: /data/mod_test/mod_test/1070.jpg
#   inflating: /data/mod_test/mod_test/1071.jpg
#   inflating: /data/mod_test/mod_test/1072.jpg
#   inflating: /data/mod_test/mod_test/1073.jpg
#   inflating: /data/mod_test/mod_test/1074.jpg
#   inflating: /data/mod_test/mod_test/1075.jpg
#   inflating: /data/mod_test/mod_test/1076.jpg
#   inflating: /data/mod_test/mod_test/1077.jpg
#   inflating: /data/mod_test/mod_test/1078.jpg
#   inflating: /data/mod_test/mod_test/1079.jpg
#   inflating: /data/mod_test/mod_test/1080.jpg
#   inflating: /data/mod_test/mod_test/1081.jpg
#   inflating: /data/mod_test/mod_test/1082.jpg
#   inflating: /data/mod_test/mod_test/1083.jpg
#   inflating: /data/mod_test/mod_test/1084.jpg
#   inflating: /data/mod_test/mod_test/1085.jpg
#   inflating: /data/mod_test/mod_test/1086.jpg
#   inflating: /data/mod_test/mod_test/1087.jpg
#   inflating: /data/mod_test/mod_test/1088.jpg
#   inflating: /data/mod_test/mod_test/1089.jpg
#   inflating: /data/mod_test/mod_test/1090.jpg
#   inflating: /data/mod_test/mod_test/1091.jpg
#   inflating: /data/mod_test/mod_test/1092.jpg
#   inflating: /data/mod_test/mod_test/1093.jpg
#   inflating: /data/mod_test/mod_test/1094.jpg
#   inflating: /data/mod_test/mod_test/1095.jpg
#   inflating: /data/mod_test/mod_test/1096.jpg
#   inflating: /data/mod_test/mod_test/1097.jpg
#   inflating: /data/mod_test/mod_test/1098.jpg
#   inflating: /data/mod_test/mod_test/1099.jpg
#   inflating: /data/mod_test/mod_test/1100.jpg
#   inflating: /data/mod_test/mod_test/1101.jpg
#   inflating: /data/mod_test/mod_test/1102.jpg
#   inflating: /data/mod_test/mod_test/1103.jpg
#   inflating: /data/mod_test/mod_test/1104.jpg
#   inflating: /data/mod_test/mod_test/1105.jpg
#   inflating: /data/mod_test/mod_test/1106.jpg
#   inflating: /data/mod_test/mod_test/1107.jpg
#   inflating: /data/mod_test/mod_test/1108.jpg
#   inflating: /data/mod_test/mod_test/1109.jpg
#   inflating: /data/mod_test/mod_test/1110.jpg
#   inflating: /data/mod_test/mod_test/1111.jpg
#   inflating: /data/mod_test/mod_test/1112.jpg
#   inflating: /data/mod_test/mod_test/1113.jpg
#   inflating: /data/mod_test/mod_test/1114.jpg
#   inflating: /data/mod_test/mod_test/1115.jpg
#   inflating: /data/mod_test/mod_test/1116.jpg
#   inflating: /data/mod_test/mod_test/1117.jpg
#   inflating: /data/mod_test/mod_test/1118.jpg
#   inflating: /data/mod_test/mod_test/1119.jpg
#   inflating: /data/mod_test/mod_test/1120.jpg
#   inflating: /data/mod_test/mod_test/1121.jpg
#   inflating: /data/mod_test/mod_test/1122.jpg
#   inflating: /data/mod_test/mod_test/1123.jpg
#   inflating: /data/mod_test/mod_test/1124.jpg
#   inflating: /data/mod_test/mod_test/1125.jpg
#   inflating: /data/mod_test/mod_test/1126.jpg
#   inflating: /data/mod_test/mod_test/1127.jpg
#   inflating: /data/mod_test/mod_test/1128.jpg
#   inflating: /data/mod_test/mod_test/1129.jpg
#   inflating: /data/mod_test/mod_test/1130.jpg
#   inflating: /data/mod_test/mod_test/1131.jpg
#   inflating: /data/mod_test/mod_test/1132.jpg
#   inflating: /data/mod_test/mod_test/1133.jpg
#   inflating: /data/mod_test/mod_test/1134.jpg
#   inflating: /data/mod_test/mod_test/1135.jpg
#   inflating: /data/mod_test/mod_test/1136.jpg
#   inflating: /data/mod_test/mod_test/1137.jpg
#   inflating: /data/mod_test/mod_test/1138.jpg
#   inflating: /data/mod_test/mod_test/1139.jpg
#   inflating: /data/mod_test/mod_test/1140.jpg
#   inflating: /data/mod_test/mod_test/1141.jpg
#   inflating: /data/mod_test/mod_test/1142.jpg
#   inflating: /data/mod_test/mod_test/1143.jpg
#   inflating: /data/mod_test/mod_test/1144.jpg
#   inflating: /data/mod_test/mod_test/1145.jpg
#   inflating: /data/mod_test/mod_test/1146.jpg
#   inflating: /data/mod_test/mod_test/1147.jpg
#   inflating: /data/mod_test/mod_test/1148.jpg
#   inflating: /data/mod_test/mod_test/1149.jpg
#   inflating: /data/mod_test/mod_test/1150.jpg
#   inflating: /data/mod_test/mod_test/1151.jpg
#   inflating: /data/mod_test/mod_test/1152.jpg
#   inflating: /data/mod_test/mod_test/1153.jpg
#   inflating: /data/mod_test/mod_test/1154.jpg
#   inflating: /data/mod_test/mod_test/1155.jpg
#   inflating: /data/mod_test/mod_test/1156.jpg
#   inflating: /data/mod_test/mod_test/1157.jpg
#   inflating: /data/mod_test/mod_test/1158.jpg
#   inflating: /data/mod_test/mod_test/1159.jpg
#   inflating: /data/mod_test/mod_test/1160.jpg
#   inflating: /data/mod_test/mod_test/1161.jpg
#   inflating: /data/mod_test/mod_test/1162.jpg
#   inflating: /data/mod_test/mod_test/1163.jpg
#   inflating: /data/mod_test/mod_test/1164.jpg
#   inflating: /data/mod_test/mod_test/1165.jpg
#   inflating: /data/mod_test/mod_test/1166.jpg
#   inflating: /data/mod_test/mod_test/1167.jpg
#   inflating: /data/mod_test/mod_test/1168.jpg
#   inflating: /data/mod_test/mod_test/1169.jpg
#   inflating: /data/mod_test/mod_test/1170.jpg
#   inflating: /data/mod_test/mod_test/1171.jpg
#   inflating: /data/mod_test/mod_test/1172.jpg
#   inflating: /data/mod_test/mod_test/1173.jpg
#   inflating: /data/mod_test/mod_test/1174.jpg
#   inflating: /data/mod_test/mod_test/1175.jpg
#   inflating: /data/mod_test/mod_test/1176.jpg
#   inflating: /data/mod_test/mod_test/1177.jpg
#   inflating: /data/mod_test/mod_test/1178.jpg
#   inflating: /data/mod_test/mod_test/1179.jpg
#   inflating: /data/mod_test/mod_test/1180.jpg
#   inflating: /data/mod_test/mod_test/1181.jpg
#   inflating: /data/mod_test/mod_test/1182.jpg
#   inflating: /data/mod_test/mod_test/1183.jpg
#   inflating: /data/mod_test/mod_test/1184.jpg
#   inflating: /data/mod_test/mod_test/1185.jpg
#   inflating: /data/mod_test/mod_test/1186.jpg
#   inflating: /data/mod_test/mod_test/1187.jpg
#   inflating: /data/mod_test/mod_test/1188.jpg
#   inflating: /data/mod_test/mod_test/1189.jpg
#   inflating: /data/mod_test/mod_test/1190.jpg
#   inflating: /data/mod_test/mod_test/1191.jpg
#   inflating: /data/mod_test/mod_test/1192.jpg
#   inflating: /data/mod_test/mod_test/1193.jpg
#   inflating: /data/mod_test/mod_test/1194.jpg
#   inflating: /data/mod_test/mod_test/1195.jpg
#   inflating: /data/mod_test/mod_test/1196.jpg
#   inflating: /data/mod_test/mod_test/1197.jpg
#   inflating: /data/mod_test/mod_test/1198.jpg
#   inflating: /data/mod_test/mod_test/1199.jpg
#   inflating: /data/mod_test/mod_test/1200.jpg
#   inflating: /data/mod_test/mod_test/1201.jpg
#   inflating: /data/mod_test/mod_test/1202.jpg
#   inflating: /data/mod_test/mod_test/1203.jpg
#   inflating: /data/mod_test/mod_test/1204.jpg
#   inflating: /data/mod_test/mod_test/1205.jpg
#   inflating: /data/mod_test/mod_test/1206.jpg
#   inflating: /data/mod_test/mod_test/1207.jpg
#   inflating: /data/mod_test/mod_test/1208.jpg
#   inflating: /data/mod_test/mod_test/1209.jpg
#   inflating: /data/mod_test/mod_test/1210.jpg
#   inflating: /data/mod_test/mod_test/1211.jpg
#   inflating: /data/mod_test/mod_test/1212.jpg
#   inflating: /data/mod_test/mod_test/1213.jpg
#   inflating: /data/mod_test/mod_test/1214.jpg
#   inflating: /data/mod_test/mod_test/1215.jpg
#   inflating: /data/mod_test/mod_test/1216.jpg
#   inflating: /data/mod_test/mod_test/1217.jpg
#   inflating: /data/mod_test/mod_test/1218.jpg
#   inflating: /data/mod_test/mod_test/1219.jpg
#   inflating: /data/mod_test/mod_test/1220.jpg
#   inflating: /data/mod_test/mod_test/1221.jpg
#   inflating: /data/mod_test/mod_test/1222.jpg
#   inflating: /data/mod_test/mod_test/1223.jpg
#   inflating: /data/mod_test/mod_test/1224.jpg
#   inflating: /data/mod_test/mod_test/1225.jpg
#   inflating: /data/mod_test/mod_test/1226.jpg
#   inflating: /data/mod_test/mod_test/1227.jpg
#   inflating: /data/mod_test/mod_test/1228.jpg
#   inflating: /data/mod_test/mod_test/1229.jpg
#   inflating: /data/mod_test/mod_test/1230.jpg
#   inflating: /data/mod_test/mod_test/1231.jpg
#   inflating: /data/mod_test/mod_test/1232.jpg
#   inflating: /data/mod_test/mod_test/1233.jpg
#   inflating: /data/mod_test/mod_test/1234.jpg
#   inflating: /data/mod_test/mod_test/1235.jpg
#   inflating: /data/mod_test/mod_test/1236.jpg
#   inflating: /data/mod_test/mod_test/1237.jpg
#   inflating: /data/mod_test/mod_test/1238.jpg
#   inflating: /data/mod_test/mod_test/1239.jpg
#   inflating: /data/mod_test/mod_test/1240.jpg
#   inflating: /data/mod_test/mod_test/1241.jpg
#   inflating: /data/mod_test/mod_test/1242.jpg
#   inflating: /data/mod_test/mod_test/1243.jpg
#   inflating: /data/mod_test/mod_test/1244.jpg
#   inflating: /data/mod_test/mod_test/1245.jpg
#   inflating: /data/mod_test/mod_test/1246.jpg
#   inflating: /data/mod_test/mod_test/1247.jpg
#   inflating: /data/mod_test/mod_test/1248.jpg
#   inflating: /data/mod_test/mod_test/1249.jpg
#   inflating: /data/mod_test/mod_test/1250.jpg
#   inflating: /data/mod_test/mod_test/1251.jpg
#   inflating: /data/mod_test/mod_test/1252.jpg
#   inflating: /data/mod_test/mod_test/1253.jpg
#   inflating: /data/mod_test/mod_test/1254.jpg
#   inflating: /data/mod_test/mod_test/1255.jpg
#   inflating: /data/mod_test/mod_test/1256.jpg
#   inflating: /data/mod_test/mod_test/1257.jpg
#   inflating: /data/mod_test/mod_test/1258.jpg
#   inflating: /data/mod_test/mod_test/1259.jpg
#   inflating: /data/mod_test/mod_test/1260.jpg
#   inflating: /data/mod_test/mod_test/1261.jpg
#   inflating: /data/mod_test/mod_test/1262.jpg
#   inflating: /data/mod_test/mod_test/1263.jpg
#   inflating: /data/mod_test/mod_test/1264.jpg
#   inflating: /data/mod_test/mod_test/1265.jpg
#   inflating: /data/mod_test/mod_test/1266.jpg
#   inflating: /data/mod_test/mod_test/1267.jpg
#   inflating: /data/mod_test/mod_test/1268.jpg
#   inflating: /data/mod_test/mod_test/1269.jpg
#   inflating: /data/mod_test/mod_test/1270.jpg
#   inflating: /data/mod_test/mod_test/1271.jpg
#   inflating: /data/mod_test/mod_test/1272.jpg
#   inflating: /data/mod_test/mod_test/1273.jpg
#   inflating: /data/mod_test/mod_test/1274.jpg
#   inflating: /data/mod_test/mod_test/1275.jpg
#   inflating: /data/mod_test/mod_test/1276.jpg
#   inflating: /data/mod_test/mod_test/1277.jpg
#   inflating: /data/mod_test/mod_test/1278.jpg
#   inflating: /data/mod_test/mod_test/1279.jpg
#   inflating: /data/mod_test/mod_test/1280.jpg
#   inflating: /data/mod_test/mod_test/1281.jpg
#   inflating: /data/mod_test/mod_test/1282.jpg
#   inflating: /data/mod_test/mod_test/1283.jpg
#   inflating: /data/mod_test/mod_test/1284.jpg
#   inflating: /data/mod_test/mod_test/1285.jpg
#   inflating: /data/mod_test/mod_test/1286.jpg
#   inflating: /data/mod_test/mod_test/1287.jpg
#   inflating: /data/mod_test/mod_test/1288.jpg
#   inflating: /data/mod_test/mod_test/1289.jpg
#   inflating: /data/mod_test/mod_test/1290.jpg
#   inflating: /data/mod_test/mod_test/1291.jpg
#   inflating: /data/mod_test/mod_test/1292.jpg
#   inflating: /data/mod_test/mod_test/1293.jpg
#   inflating: /data/mod_test/mod_test/1294.jpg
#   inflating: /data/mod_test/mod_test/1295.jpg
#   inflating: /data/mod_test/mod_test/1296.jpg
#   inflating: /data/mod_test/mod_test/1297.jpg
#   inflating: /data/mod_test/mod_test/1298.jpg
#   inflating: /data/mod_test/mod_test/1299.jpg
#   inflating: /data/mod_test/mod_test/1300.jpg
#   inflating: /data/mod_test/mod_test/1301.jpg
#   inflating: /data/mod_test/mod_test/1302.jpg
#   inflating: /data/mod_test/mod_test/1303.jpg
#   inflating: /data/mod_test/mod_test/1304.jpg
#   inflating: /data/mod_test/mod_test/1305.jpg
#   inflating: /data/mod_test/mod_test/1306.jpg
#   inflating: /data/mod_test/mod_test/1307.jpg
#   inflating: /data/mod_test/mod_test/1308.jpg
#   inflating: /data/mod_test/mod_test/1309.jpg
#   inflating: /data/mod_test/mod_test/1310.jpg
#   inflating: /data/mod_test/mod_test/1311.jpg
#   inflating: /data/mod_test/mod_test/1312.jpg
#   inflating: /data/mod_test/mod_test/1313.jpg
#   inflating: /data/mod_test/mod_test/1314.jpg
#   inflating: /data/mod_test/mod_test/1315.jpg
#   inflating: /data/mod_test/mod_test/1316.jpg
#   inflating: /data/mod_test/mod_test/1317.jpg
#   inflating: /data/mod_test/mod_test/1318.jpg
#   inflating: /data/mod_test/mod_test/1319.jpg
#   inflating: /data/mod_test/mod_test/1320.jpg
#   inflating: /data/mod_test/mod_test/1321.jpg
#   inflating: /data/mod_test/mod_test/1322.jpg
#   inflating: /data/mod_test/mod_test/1323.jpg
#   inflating: /data/mod_test/mod_test/1324.jpg
#   inflating: /data/mod_test/mod_test/1325.jpg
#   inflating: /data/mod_test/mod_test/1326.jpg
#   inflating: /data/mod_test/mod_test/1327.jpg
#   inflating: /data/mod_test/mod_test/1328.jpg
#   inflating: /data/mod_test/mod_test/1329.jpg
#   inflating: /data/mod_test/mod_test/1330.jpg
#   inflating: /data/mod_test/mod_test/1331.jpg
#   inflating: /data/mod_test/mod_test/1332.jpg
#   inflating: /data/mod_test/mod_test/1333.jpg
#   inflating: /data/mod_test/mod_test/1334.jpg
#   inflating: /data/mod_test/mod_test/1335.jpg
#   inflating: /data/mod_test/mod_test/1336.jpg
#   inflating: /data/mod_test/mod_test/1337.jpg
#   inflating: /data/mod_test/mod_test/1338.jpg
#   inflating: /data/mod_test/mod_test/1339.jpg
#   inflating: /data/mod_test/mod_test/1340.jpg
#   inflating: /data/mod_test/mod_test/1341.jpg
#   inflating: /data/mod_test/mod_test/1342.jpg
#   inflating: /data/mod_test/mod_test/1343.jpg
#   inflating: /data/mod_test/mod_test/1344.jpg
#   inflating: /data/mod_test/mod_test/1345.jpg
#   inflating: /data/mod_test/mod_test/1346.jpg
#   inflating: /data/mod_test/mod_test/1347.jpg
#   inflating: /data/mod_test/mod_test/1348.jpg
#   inflating: /data/mod_test/mod_test/1349.jpg
#   inflating: /data/mod_test/mod_test/1350.jpg
#   inflating: /data/mod_test/mod_test/1351.jpg
#   inflating: /data/mod_test/mod_test/1352.jpg
#   inflating: /data/mod_test/mod_test/1353.jpg
#   inflating: /data/mod_test/mod_test/1354.jpg
#   inflating: /data/mod_test/mod_test/1355.jpg
#   inflating: /data/mod_test/mod_test/1356.jpg
#   inflating: /data/mod_test/mod_test/1357.jpg
#   inflating: /data/mod_test/mod_test/1358.jpg
#   inflating: /data/mod_test/mod_test/1359.jpg
#   inflating: /data/mod_test/mod_test/1360.jpg
#   inflating: /data/mod_test/mod_test/1361.jpg
#   inflating: /data/mod_test/mod_test/1362.jpg
#   inflating: /data/mod_test/mod_test/1363.jpg
#   inflating: /data/mod_test/mod_test/1364.jpg
#   inflating: /data/mod_test/mod_test/1365.jpg
#   inflating: /data/mod_test/mod_test/1366.jpg
#   inflating: /data/mod_test/mod_test/1367.jpg
#   inflating: /data/mod_test/mod_test/1368.jpg
#   inflating: /data/mod_test/mod_test/1369.jpg
#   inflating: /data/mod_test/mod_test/1370.jpg
#   inflating: /data/mod_test/mod_test/1371.jpg
#   inflating: /data/mod_test/mod_test/1372.jpg
#   inflating: /data/mod_test/mod_test/1373.jpg
#   inflating: /data/mod_test/mod_test/1374.jpg
#   inflating: /data/mod_test/mod_test/1375.jpg
#   inflating: /data/mod_test/mod_test/1376.jpg
#   inflating: /data/mod_test/mod_test/1377.jpg
#   inflating: /data/mod_test/mod_test/1378.jpg
#   inflating: /data/mod_test/mod_test/1379.jpg
#   inflating: /data/mod_test/mod_test/1380.jpg
#   inflating: /data/mod_test/mod_test/1381.jpg
#   inflating: /data/mod_test/mod_test/1382.jpg
#   inflating: /data/mod_test/mod_test/1383.jpg
#   inflating: /data/mod_test/mod_test/1384.jpg
#   inflating: /data/mod_test/mod_test/1385.jpg
#   inflating: /data/mod_test/mod_test/1386.jpg
#   inflating: /data/mod_test/mod_test/1387.jpg
#   inflating: /data/mod_test/mod_test/1388.jpg
#   inflating: /data/mod_test/mod_test/1389.jpg
#   inflating: /data/mod_test/mod_test/1390.jpg
#   inflating: /data/mod_test/mod_test/1391.jpg
#   inflating: /data/mod_test/mod_test/1392.jpg
#   inflating: /data/mod_test/mod_test/1393.jpg
#   inflating: /data/mod_test/mod_test/1394.jpg
#   inflating: /data/mod_test/mod_test/1395.jpg
#   inflating: /data/mod_test/mod_test/1396.jpg
#   inflating: /data/mod_test/mod_test/1397.jpg
#   inflating: /data/mod_test/mod_test/1398.jpg
#   inflating: /data/mod_test/mod_test/1399.jpg
#   inflating: /data/mod_test/mod_test/1400.jpg
#   inflating: /data/mod_test/mod_test/1401.jpg
#   inflating: /data/mod_test/mod_test/1402.jpg
#   inflating: /data/mod_test/mod_test/1403.jpg
#   inflating: /data/mod_test/mod_test/1404.jpg
#   inflating: /data/mod_test/mod_test/1405.jpg
#   inflating: /data/mod_test/mod_test/1406.jpg
#   inflating: /data/mod_test/mod_test/1407.jpg
#   inflating: /data/mod_test/mod_test/1408.jpg
#   inflating: /data/mod_test/mod_test/1409.jpg
#   inflating: /data/mod_test/mod_test/1410.jpg
#   inflating: /data/mod_test/mod_test/1411.jpg
#   inflating: /data/mod_test/mod_test/1412.jpg
#   inflating: /data/mod_test/mod_test/1413.jpg
#   inflating: /data/mod_test/mod_test/1414.jpg
#   inflating: /data/mod_test/mod_test/1415.jpg
#   inflating: /data/mod_test/mod_test/1416.jpg
#   inflating: /data/mod_test/mod_test/1417.jpg
#   inflating: /data/mod_test/mod_test/1418.jpg
#   inflating: /data/mod_test/mod_test/1419.jpg
#   inflating: /data/mod_test/mod_test/1420.jpg
#   inflating: /data/mod_test/mod_test/1421.jpg
#   inflating: /data/mod_test/mod_test/1422.jpg
#   inflating: /data/mod_test/mod_test/1423.jpg
#   inflating: /data/mod_test/mod_test/1424.jpg
#   inflating: /data/mod_test/mod_test/1425.jpg
#   inflating: /data/mod_test/mod_test/1426.jpg
#   inflating: /data/mod_test/mod_test/1427.jpg
#   inflating: /data/mod_test/mod_test/1428.jpg
#   inflating: /data/mod_test/mod_test/1429.jpg
#   inflating: /data/mod_test/mod_test/1430.jpg
#   inflating: /data/mod_test/mod_test/1431.jpg
#   inflating: /data/mod_test/mod_test/1432.jpg
#   inflating: /data/mod_test/mod_test/1433.jpg
#   inflating: /data/mod_test/mod_test/1434.jpg
#   inflating: /data/mod_test/mod_test/1435.jpg
#   inflating: /data/mod_test/mod_test/1436.jpg
#   inflating: /data/mod_test/mod_test/1437.jpg
#   inflating: /data/mod_test/mod_test/1438.jpg
#   inflating: /data/mod_test/mod_test/1439.jpg
#   inflating: /data/mod_test/mod_test/1440.jpg
#   inflating: /data/mod_test/mod_test/1441.jpg
#   inflating: /data/mod_test/mod_test/1442.jpg
#   inflating: /data/mod_test/mod_test/1443.jpg
#   inflating: /data/mod_test/mod_test/1444.jpg
#   inflating: /data/mod_test/mod_test/1445.jpg
#   inflating: /data/mod_test/mod_test/1446.jpg
#   inflating: /data/mod_test/mod_test/1447.jpg
#   inflating: /data/mod_test/mod_test/1448.jpg
#   inflating: /data/mod_test/mod_test/1449.jpg
#   inflating: /data/mod_test/mod_test/1450.jpg
#   inflating: /data/mod_test/mod_test/1451.jpg
#   inflating: /data/mod_test/mod_test/1452.jpg
#   inflating: /data/mod_test/mod_test/1453.jpg
#   inflating: /data/mod_test/mod_test/1454.jpg
#   inflating: /data/mod_test/mod_test/1455.jpg
#   inflating: /data/mod_test/mod_test/1456.jpg
#   inflating: /data/mod_test/mod_test/1457.jpg
#   inflating: /data/mod_test/mod_test/1458.jpg
#   inflating: /data/mod_test/mod_test/1459.jpg
#   inflating: /data/mod_test/mod_test/1460.jpg
#   inflating: /data/mod_test/mod_test/1461.jpg
#   inflating: /data/mod_test/mod_test/1462.jpg
#   inflating: /data/mod_test/mod_test/1463.jpg
#   inflating: /data/mod_test/mod_test/1464.jpg
#   inflating: /data/mod_test/mod_test/1465.jpg
#   inflating: /data/mod_test/mod_test/1466.jpg
#   inflating: /data/mod_test/mod_test/1467.jpg
#   inflating: /data/mod_test/mod_test/1468.jpg
#   inflating: /data/mod_test/mod_test/1469.jpg
#   inflating: /data/mod_test/mod_test/1470.jpg
#   inflating: /data/mod_test/mod_test/1471.jpg
#   inflating: /data/mod_test/mod_test/1472.jpg
#   inflating: /data/mod_test/mod_test/1473.jpg
#   inflating: /data/mod_test/mod_test/1474.jpg
#   inflating: /data/mod_test/mod_test/1475.jpg
#   inflating: /data/mod_test/mod_test/1476.jpg
#   inflating: /data/mod_test/mod_test/1477.jpg
#   inflating: /data/mod_test/mod_test/1478.jpg
#   inflating: /data/mod_test/mod_test/1479.jpg
#   inflating: /data/mod_test/mod_test/1480.jpg
#   inflating: /data/mod_test/mod_test/1481.jpg
#   inflating: /data/mod_test/mod_test/1482.jpg
#   inflating: /data/mod_test/mod_test/1483.jpg
#   inflating: /data/mod_test/mod_test/1484.jpg
#   inflating: /data/mod_test/mod_test/1485.jpg
#   inflating: /data/mod_test/mod_test/1486.jpg
#   inflating: /data/mod_test/mod_test/1487.jpg
#   inflating: /data/mod_test/mod_test/1488.jpg
#   inflating: /data/mod_test/mod_test/1489.jpg
#   inflating: /data/mod_test/mod_test/1490.jpg
#   inflating: /data/mod_test/mod_test/1491.jpg
#   inflating: /data/mod_test/mod_test/1492.jpg
#   inflating: /data/mod_test/mod_test/1493.jpg
#   inflating: /data/mod_test/mod_test/1494.jpg
#   inflating: /data/mod_test/mod_test/1495.jpg
#   inflating: /data/mod_test/mod_test/1496.jpg
#   inflating: /data/mod_test/mod_test/1497.jpg
#   inflating: /data/mod_test/mod_test/1498.jpg
#   inflating: /data/mod_test/mod_test/1499.jpg
#   inflating: /data/mod_test/mod_test/1500.jpg
#   inflating: /data/mod_test/mod_test/1501.jpg
#   inflating: /data/mod_test/mod_test/1502.jpg
#   inflating: /data/mod_test/mod_test/1503.jpg
#   inflating: /data/mod_test/mod_test/1504.jpg
#   inflating: /data/mod_test/mod_test/1505.jpg
#   inflating: /data/mod_test/mod_test/1506.jpg
#   inflating: /data/mod_test/mod_test/1507.jpg
#   inflating: /data/mod_test/mod_test/1508.jpg
#   inflating: /data/mod_test/mod_test/1509.jpg
#   inflating: /data/mod_test/mod_test/1510.jpg
#   inflating: /data/mod_test/mod_test/1511.jpg
#   inflating: /data/mod_test/mod_test/1512.jpg
#   inflating: /data/mod_test/mod_test/1513.jpg
#   inflating: /data/mod_test/mod_test/1514.jpg
#   inflating: /data/mod_test/mod_test/1515.jpg
#   inflating: /data/mod_test/mod_test/1516.jpg
#   inflating: /data/mod_test/mod_test/1517.jpg
#   inflating: /data/mod_test/mod_test/1518.jpg
#   inflating: /data/mod_test/mod_test/1519.jpg
#   inflating: /data/mod_test/mod_test/1520.jpg
#   inflating: /data/mod_test/mod_test/1521.jpg
#   inflating: /data/mod_test/mod_test/1522.jpg
#   inflating: /data/mod_test/mod_test/1523.jpg
#   inflating: /data/mod_test/mod_test/1524.jpg
#   inflating: /data/mod_test/mod_test/1525.jpg
#   inflating: /data/mod_test/mod_test/1526.jpg
#   inflating: /data/mod_test/mod_test/1527.jpg
#   inflating: /data/mod_test/mod_test/1528.jpg
#   inflating: /data/mod_test/mod_test/1529.jpg
#   inflating: /data/mod_test/mod_test/1530.jpg
#   inflating: /data/mod_test/mod_test/1531.jpg
#   inflating: /data/mod_test/mod_test/1532.jpg
#   inflating: /data/mod_test/mod_test/1533.jpg
#   inflating: /data/mod_test/mod_test/1534.jpg
#   inflating: /data/mod_test/mod_test/1535.jpg
#   inflating: /data/mod_test/mod_test/1536.jpg
#   inflating: /data/mod_test/mod_test/1537.jpg
#   inflating: /data/mod_test/mod_test/1538.jpg
#   inflating: /data/mod_test/mod_test/1539.jpg
#   inflating: /data/mod_test/mod_test/1540.jpg
#   inflating: /data/mod_test/mod_test/1541.jpg
#   inflating: /data/mod_test/mod_test/1542.jpg
#   inflating: /data/mod_test/mod_test/1543.jpg
#   inflating: /data/mod_test/mod_test/1544.jpg
#   inflating: /data/mod_test/mod_test/1545.jpg
#   inflating: /data/mod_test/mod_test/1546.jpg
#   inflating: /data/mod_test/mod_test/1547.jpg
#   inflating: /data/mod_test/mod_test/1548.jpg
#   inflating: /data/mod_test/mod_test/1549.jpg
#   inflating: /data/mod_test/mod_test/1550.jpg
#   inflating: /data/mod_test/mod_test/1551.jpg
#   inflating: /data/mod_test/mod_test/1552.jpg
#   inflating: /data/mod_test/mod_test/1553.jpg
#   inflating: /data/mod_test/mod_test/1554.jpg
#   inflating: /data/mod_test/mod_test/1555.jpg
#   inflating: /data/mod_test/mod_test/1556.jpg
#   inflating: /data/mod_test/mod_test/1557.jpg
#   inflating: /data/mod_test/mod_test/1558.jpg
#   inflating: /data/mod_test/mod_test/1559.jpg
#   inflating: /data/mod_test/mod_test/1560.jpg
#   inflating: /data/mod_test/mod_test/1561.jpg
#   inflating: /data/mod_test/mod_test/1562.jpg
#   inflating: /data/mod_test/mod_test/1563.jpg
#   inflating: /data/mod_test/mod_test/1564.jpg
#   inflating: /data/mod_test/mod_test/1565.jpg
#   inflating: /data/mod_test/mod_test/1566.jpg
#   inflating: /data/mod_test/mod_test/1567.jpg
#   inflating: /data/mod_test/mod_test/1568.jpg
#   inflating: /data/mod_test/mod_test/1569.jpg
#   inflating: /data/mod_test/mod_test/1570.jpg
#   inflating: /data/mod_test/mod_test/1571.jpg
#   inflating: /data/mod_test/mod_test/1572.jpg
#   inflating: /data/mod_test/mod_test/1573.jpg
#   inflating: /data/mod_test/mod_test/1574.jpg
#   inflating: /data/mod_test/mod_test/1575.jpg
#   inflating: /data/mod_test/mod_test/1576.jpg
#   inflating: /data/mod_test/mod_test/1577.jpg
#   inflating: /data/mod_test/mod_test/1578.jpg
#   inflating: /data/mod_test/mod_test/1579.jpg
#   inflating: /data/mod_test/mod_test/1580.jpg
#   inflating: /data/mod_test/mod_test/1581.jpg
#   inflating: /data/mod_test/mod_test/1582.jpg
#   inflating: /data/mod_test/mod_test/1583.jpg
#   inflating: /data/mod_test/mod_test/1584.jpg
#   inflating: /data/mod_test/mod_test/1585.jpg
#   inflating: /data/mod_test/mod_test/1586.jpg
#   inflating: /data/mod_test/mod_test/1587.jpg
#   inflating: /data/mod_test/mod_test/1588.jpg
#   inflating: /data/mod_test/mod_test/1589.jpg
#   inflating: /data/mod_test/mod_test/1590.jpg
#   inflating: /data/mod_test/mod_test/1591.jpg
#   inflating: /data/mod_test/mod_test/1592.jpg
#   inflating: /data/mod_test/mod_test/1593.jpg
#   inflating: /data/mod_test/mod_test/1594.jpg
#   inflating: /data/mod_test/mod_test/1595.jpg
#   inflating: /data/mod_test/mod_test/1596.jpg
#   inflating: /data/mod_test/mod_test/1597.jpg
#   inflating: /data/mod_test/mod_test/1598.jpg
#   inflating: /data/mod_test/mod_test/1599.jpg
#   inflating: /data/mod_test/mod_test/1600.jpg
#   inflating: /data/mod_test/mod_test/1601.jpg
#   inflating: /data/mod_test/mod_test/1602.jpg
#   inflating: /data/mod_test/mod_test/1603.jpg
#   inflating: /data/mod_test/mod_test/1604.jpg
#   inflating: /data/mod_test/mod_test/1605.jpg
#   inflating: /data/mod_test/mod_test/1606.jpg
#   inflating: /data/mod_test/mod_test/1607.jpg
#   inflating: /data/mod_test/mod_test/1608.jpg
#   inflating: /data/mod_test/mod_test/1609.jpg
#   inflating: /data/mod_test/mod_test/1610.jpg
#   inflating: /data/mod_test/mod_test/1611.jpg
#   inflating: /data/mod_test/mod_test/1612.jpg
#   inflating: /data/mod_test/mod_test/1613.jpg
#   inflating: /data/mod_test/mod_test/1614.jpg
#   inflating: /data/mod_test/mod_test/1615.jpg
#   inflating: /data/mod_test/mod_test/1616.jpg
#   inflating: /data/mod_test/mod_test/1617.jpg
#   inflating: /data/mod_test/mod_test/1618.jpg
#   inflating: /data/mod_test/mod_test/1619.jpg
#   inflating: /data/mod_test/mod_test/1620.jpg
#   inflating: /data/mod_test/mod_test/1621.jpg
#   inflating: /data/mod_test/mod_test/1622.jpg
#   inflating: /data/mod_test/mod_test/1623.jpg
#   inflating: /data/mod_test/mod_test/1624.jpg
#   inflating: /data/mod_test/mod_test/1625.jpg
#   inflating: /data/mod_test/mod_test/1626.jpg
#   inflating: /data/mod_test/mod_test/1627.jpg
#   inflating: /data/mod_test/mod_test/1628.jpg
#   inflating: /data/mod_test/mod_test/1629.jpg
#   inflating: /data/mod_test/mod_test/1630.jpg
#   inflating: /data/mod_test/mod_test/1631.jpg
#   inflating: /data/mod_test/mod_test/1632.jpg
#   inflating: /data/mod_test/mod_test/1633.jpg
#   inflating: /data/mod_test/mod_test/1634.jpg
#   inflating: /data/mod_test/mod_test/1635.jpg
#   inflating: /data/mod_test/mod_test/1636.jpg
#   inflating: /data/mod_test/mod_test/1637.jpg
#   inflating: /data/mod_test/mod_test/1638.jpg
#   inflating: /data/mod_test/mod_test/1639.jpg
#   inflating: /data/mod_test/mod_test/1640.jpg
#   inflating: /data/mod_test/mod_test/1641.jpg
#   inflating: /data/mod_test/mod_test/1642.jpg
#   inflating: /data/mod_test/mod_test/1643.jpg
#   inflating: /data/mod_test/mod_test/1644.jpg
#   inflating: /data/mod_test/mod_test/1645.jpg
#   inflating: /data/mod_test/mod_test/1646.jpg
#   inflating: /data/mod_test/mod_test/1647.jpg
#   inflating: /data/mod_test/mod_test/1648.jpg
#   inflating: /data/mod_test/mod_test/1649.jpg
#   inflating: /data/mod_test/mod_test/1650.jpg
#   inflating: /data/mod_test/mod_test/1651.jpg
#   inflating: /data/mod_test/mod_test/1652.jpg
#   inflating: /data/mod_test/mod_test/1653.jpg
#   inflating: /data/mod_test/mod_test/1654.jpg
#   inflating: /data/mod_test/mod_test/1655.jpg
#   inflating: /data/mod_test/mod_test/1656.jpg
#   inflating: /data/mod_test/mod_test/1657.jpg
#   inflating: /data/mod_test/mod_test/1658.jpg
#   inflating: /data/mod_test/mod_test/1659.jpg
#   inflating: /data/mod_test/mod_test/1660.jpg
#   inflating: /data/mod_test/mod_test/1661.jpg
#   inflating: /data/mod_test/mod_test/1662.jpg
#   inflating: /data/mod_test/mod_test/1663.jpg
#   inflating: /data/mod_test/mod_test/1664.jpg
#   inflating: /data/mod_test/mod_test/1665.jpg
#   inflating: /data/mod_test/mod_test/1666.jpg
#   inflating: /data/mod_test/mod_test/1667.jpg
#   inflating: /data/mod_test/mod_test/1668.jpg
#   inflating: /data/mod_test/mod_test/1669.jpg
#   inflating: /data/mod_test/mod_test/1670.jpg
#   inflating: /data/mod_test/mod_test/1671.jpg
#   inflating: /data/mod_test/mod_test/1672.jpg
#   inflating: /data/mod_test/mod_test/1673.jpg
#   inflating: /data/mod_test/mod_test/1674.jpg
#   inflating: /data/mod_test/mod_test/1675.jpg
#   inflating: /data/mod_test/mod_test/1676.jpg
#   inflating: /data/mod_test/mod_test/1677.jpg
#   inflating: /data/mod_test/mod_test/1678.jpg
#   inflating: /data/mod_test/mod_test/1679.jpg
#   inflating: /data/mod_test/mod_test/1680.jpg
#   inflating: /data/mod_test/mod_test/1681.jpg
#   inflating: /data/mod_test/mod_test/1682.jpg
#   inflating: /data/mod_test/mod_test/1683.jpg
#   inflating: /data/mod_test/mod_test/1684.jpg
#   inflating: /data/mod_test/mod_test/1685.jpg
#   inflating: /data/mod_test/mod_test/1686.jpg
#   inflating: /data/mod_test/mod_test/1687.jpg
#   inflating: /data/mod_test/mod_test/1688.jpg
#   inflating: /data/mod_test/mod_test/1689.jpg
#   inflating: /data/mod_test/mod_test/1690.jpg
#   inflating: /data/mod_test/mod_test/1691.jpg
#   inflating: /data/mod_test/mod_test/1692.jpg
#   inflating: /data/mod_test/mod_test/1693.jpg
#   inflating: /data/mod_test/mod_test/1694.jpg
#   inflating: /data/mod_test/mod_test/1695.jpg
#   inflating: /data/mod_test/mod_test/1696.jpg
#   inflating: /data/mod_test/mod_test/1697.jpg
#   inflating: /data/mod_test/mod_test/1698.jpg
#   inflating: /data/mod_test/mod_test/1699.jpg
#   inflating: /data/mod_test/mod_test/1700.jpg
#   inflating: /data/mod_test/mod_test/1701.jpg
#   inflating: /data/mod_test/mod_test/1702.jpg
#   inflating: /data/mod_test/mod_test/1703.jpg
#   inflating: /data/mod_test/mod_test/1704.jpg
#   inflating: /data/mod_test/mod_test/1705.jpg
#   inflating: /data/mod_test/mod_test/1706.jpg
#   inflating: /data/mod_test/mod_test/1707.jpg
#   inflating: /data/mod_test/mod_test/1708.jpg
#   inflating: /data/mod_test/mod_test/1709.jpg
#   inflating: /data/mod_test/mod_test/1710.jpg
#   inflating: /data/mod_test/mod_test/1711.jpg
#   inflating: /data/mod_test/mod_test/1712.jpg
#   inflating: /data/mod_test/mod_test/1713.jpg
#   inflating: /data/mod_test/mod_test/1714.jpg
#   inflating: /data/mod_test/mod_test/1715.jpg
#   inflating: /data/mod_test/mod_test/1716.jpg
#   inflating: /data/mod_test/mod_test/1717.jpg
#   inflating: /data/mod_test/mod_test/1718.jpg
#   inflating: /data/mod_test/mod_test/1719.jpg
#   inflating: /data/mod_test/mod_test/1720.jpg
#   inflating: /data/mod_test/mod_test/1721.jpg
#   inflating: /data/mod_test/mod_test/1722.jpg
#   inflating: /data/mod_test/mod_test/1723.jpg
#   inflating: /data/mod_test/mod_test/1724.jpg
#   inflating: /data/mod_test/mod_test/1725.jpg
#   inflating: /data/mod_test/mod_test/1726.jpg
#   inflating: /data/mod_test/mod_test/1727.jpg
#   inflating: /data/mod_test/mod_test/1728.jpg
#   inflating: /data/mod_test/mod_test/1729.jpg
#   inflating: /data/mod_test/mod_test/1730.jpg
#   inflating: /data/mod_test/mod_test/1731.jpg
#   inflating: /data/mod_test/mod_test/1732.jpg
#   inflating: /data/mod_test/mod_test/1733.jpg
#   inflating: /data/mod_test/mod_test/1734.jpg
#   inflating: /data/mod_test/mod_test/1735.jpg
#   inflating: /data/mod_test/mod_test/1736.jpg
#   inflating: /data/mod_test/mod_test/1737.jpg
#   inflating: /data/mod_test/mod_test/1738.jpg
#   inflating: /data/mod_test/mod_test/1739.jpg
#   inflating: /data/mod_test/mod_test/1740.jpg
#   inflating: /data/mod_test/mod_test/1741.jpg
#   inflating: /data/mod_test/mod_test/1742.jpg
#   inflating: /data/mod_test/mod_test/1743.jpg
#   inflating: /data/mod_test/mod_test/1744.jpg
#   inflating: /data/mod_test/mod_test/1745.jpg
#   inflating: /data/mod_test/mod_test/1746.jpg
#   inflating: /data/mod_test/mod_test/1747.jpg
#   inflating: /data/mod_test/mod_test/1748.jpg
#   inflating: /data/mod_test/mod_test/1749.jpg
#   inflating: /data/mod_test/mod_test/1750.jpg
#   inflating: /data/mod_test/mod_test/1751.jpg
#   inflating: /data/mod_test/mod_test/1752.jpg
#   inflating: /data/mod_test/mod_test/1753.jpg
#   inflating: /data/mod_test/mod_test/1754.jpg
#   inflating: /data/mod_test/mod_test/1755.jpg
#   inflating: /data/mod_test/mod_test/1756.jpg
#   inflating: /data/mod_test/mod_test/1757.jpg
#   inflating: /data/mod_test/mod_test/1758.jpg
#   inflating: /data/mod_test/mod_test/1759.jpg
#   inflating: /data/mod_test/mod_test/1760.jpg
#   inflating: /data/mod_test/mod_test/1761.jpg
#   inflating: /data/mod_test/mod_test/1762.jpg
#   inflating: /data/mod_test/mod_test/1763.jpg
#   inflating: /data/mod_test/mod_test/1764.jpg
#   inflating: /data/mod_test/mod_test/1765.jpg
#   inflating: /data/mod_test/mod_test/1766.jpg
#   inflating: /data/mod_test/mod_test/1767.jpg
#   inflating: /data/mod_test/mod_test/1768.jpg
#   inflating: /data/mod_test/mod_test/1769.jpg
#   inflating: /data/mod_test/mod_test/1770.jpg
#   inflating: /data/mod_test/mod_test/1771.jpg
#   inflating: /data/mod_test/mod_test/1772.jpg
#   inflating: /data/mod_test/mod_test/1773.jpg
#   inflating: /data/mod_test/mod_test/1774.jpg
#   inflating: /data/mod_test/mod_test/1775.jpg
#   inflating: /data/mod_test/mod_test/1776.jpg
#   inflating: /data/mod_test/mod_test/1777.jpg
#   inflating: /data/mod_test/mod_test/1778.jpg
#   inflating: /data/mod_test/mod_test/1779.jpg
#   inflating: /data/mod_test/mod_test/1780.jpg
#   inflating: /data/mod_test/mod_test/1781.jpg
#   inflating: /data/mod_test/mod_test/1782.jpg
#   inflating: /data/mod_test/mod_test/1783.jpg
#   inflating: /data/mod_test/mod_test/1784.jpg
#   inflating: /data/mod_test/mod_test/1785.jpg
#   inflating: /data/mod_test/mod_test/1786.jpg
#   inflating: /data/mod_test/mod_test/1787.jpg
#   inflating: /data/mod_test/mod_test/1788.jpg
#   inflating: /data/mod_test/mod_test/1789.jpg
#   inflating: /data/mod_test/mod_test/1790.jpg
#   inflating: /data/mod_test/mod_test/1791.jpg
#   inflating: /data/mod_test/mod_test/1792.jpg
#   inflating: /data/mod_test/mod_test/1793.jpg
#   inflating: /data/mod_test/mod_test/1794.jpg
#   inflating: /data/mod_test/mod_test/1795.jpg
#   inflating: /data/mod_test/mod_test/1796.jpg
#   inflating: /data/mod_test/mod_test/1797.jpg
#   inflating: /data/mod_test/mod_test/1798.jpg
#   inflating: /data/mod_test/mod_test/1799.jpg
#   inflating: /data/mod_test/mod_test/1800.jpg
#   inflating: /data/mod_test/mod_test/1801.jpg
#   inflating: /data/mod_test/mod_test/1802.jpg
#   inflating: /data/mod_test/mod_test/1803.jpg
#   inflating: /data/mod_test/mod_test/1804.jpg
#   inflating: /data/mod_test/mod_test/1805.jpg
#   inflating: /data/mod_test/mod_test/1806.jpg
#   inflating: /data/mod_test/mod_test/1807.jpg
#   inflating: /data/mod_test/mod_test/1808.jpg
#   inflating: /data/mod_test/mod_test/1809.jpg
#   inflating: /data/mod_test/mod_test/1810.jpg
#   inflating: /data/mod_test/mod_test/1811.jpg
#   inflating: /data/mod_test/mod_test/1812.jpg
#   inflating: /data/mod_test/mod_test/1813.jpg
#   inflating: /data/mod_test/mod_test/1814.jpg
#   inflating: /data/mod_test/mod_test/1815.jpg
#   inflating: /data/mod_test/mod_test/1816.jpg
#   inflating: /data/mod_test/mod_test/1817.jpg
#   inflating: /data/mod_test/mod_test/1818.jpg
#   inflating: /data/mod_test/mod_test/1819.jpg
#   inflating: /data/mod_test/mod_test/1820.jpg
#   inflating: /data/mod_test/mod_test/1821.jpg
#   inflating: /data/mod_test/mod_test/1822.jpg
#   inflating: /data/mod_test/mod_test/1823.jpg
#   inflating: /data/mod_test/mod_test/1824.jpg
#   inflating: /data/mod_test/mod_test/1825.jpg
#   inflating: /data/mod_test/mod_test/1826.jpg
#   inflating: /data/mod_test/mod_test/1827.jpg
#   inflating: /data/mod_test/mod_test/1828.jpg
#   inflating: /data/mod_test/mod_test/1829.jpg
#   inflating: /data/mod_test/mod_test/1830.jpg
#   inflating: /data/mod_test/mod_test/1831.jpg
#   inflating: /data/mod_test/mod_test/1832.jpg
#   inflating: /data/mod_test/mod_test/1833.jpg
#   inflating: /data/mod_test/mod_test/1834.jpg
#   inflating: /data/mod_test/mod_test/1835.jpg
#   inflating: /data/mod_test/mod_test/1836.jpg
#   inflating: /data/mod_test/mod_test/1837.jpg
#   inflating: /data/mod_test/mod_test/1838.jpg
#   inflating: /data/mod_test/mod_test/1839.jpg
#   inflating: /data/mod_test/mod_test/1840.jpg
#   inflating: /data/mod_test/mod_test/1841.jpg
#   inflating: /data/mod_test/mod_test/1842.jpg
#   inflating: /data/mod_test/mod_test/1843.jpg
#   inflating: /data/mod_test/mod_test/1844.jpg
#   inflating: /data/mod_test/mod_test/1845.jpg
#   inflating: /data/mod_test/mod_test/1846.jpg
#   inflating: /data/mod_test/mod_test/1847.jpg
#   inflating: /data/mod_test/mod_test/1848.jpg
#   inflating: /data/mod_test/mod_test/1849.jpg
#   inflating: /data/mod_test/mod_test/1850.jpg
#   inflating: /data/mod_test/mod_test/1851.jpg
#   inflating: /data/mod_test/mod_test/1852.jpg
#   inflating: /data/mod_test/mod_test/1853.jpg
#   inflating: /data/mod_test/mod_test/1854.jpg
#   inflating: /data/mod_test/mod_test/1855.jpg
#   inflating: /data/mod_test/mod_test/1856.jpg
#   inflating: /data/mod_test/mod_test/1857.jpg
#   inflating: /data/mod_test/mod_test/1858.jpg
#   inflating: /data/mod_test/mod_test/1859.jpg
#   inflating: /data/mod_test/mod_test/1860.jpg
#   inflating: /data/mod_test/mod_test/1861.jpg
#   inflating: /data/mod_test/mod_test/1862.jpg
#   inflating: /data/mod_test/mod_test/1863.jpg
#   inflating: /data/mod_test/mod_test/1864.jpg
#   inflating: /data/mod_test/mod_test/1865.jpg
#   inflating: /data/mod_test/mod_test/1866.jpg
#   inflating: /data/mod_test/mod_test/1867.jpg
#   inflating: /data/mod_test/mod_test/1868.jpg
#   inflating: /data/mod_test/mod_test/1869.jpg
#   inflating: /data/mod_test/mod_test/1870.jpg
#   inflating: /data/mod_test/mod_test/1871.jpg
#   inflating: /data/mod_test/mod_test/1872.jpg
#   inflating: /data/mod_test/mod_test/1873.jpg
#   inflating: /data/mod_test/mod_test/1874.jpg
#   inflating: /data/mod_test/mod_test/1875.jpg
#   inflating: /data/mod_test/mod_test/1876.jpg
#   inflating: /data/mod_test/mod_test/1877.jpg
#   inflating: /data/mod_test/mod_test/1878.jpg
#   inflating: /data/mod_test/mod_test/1879.jpg
#   inflating: /data/mod_test/mod_test/1880.jpg
#   inflating: /data/mod_test/mod_test/1881.jpg
#   inflating: /data/mod_test/mod_test/1882.jpg
#   inflating: /data/mod_test/mod_test/1883.jpg
#   inflating: /data/mod_test/mod_test/1884.jpg
#   inflating: /data/mod_test/mod_test/1885.jpg
#   inflating: /data/mod_test/mod_test/1886.jpg
#   inflating: /data/mod_test/mod_test/1887.jpg
#   inflating: /data/mod_test/mod_test/1888.jpg
#   inflating: /data/mod_test/mod_test/1889.jpg
#   inflating: /data/mod_test/mod_test/1890.jpg
#   inflating: /data/mod_test/mod_test/1891.jpg
#   inflating: /data/mod_test/mod_test/1892.jpg
#   inflating: /data/mod_test/mod_test/1893.jpg
#   inflating: /data/mod_test/mod_test/1894.jpg
#   inflating: /data/mod_test/mod_test/1895.jpg
#   inflating: /data/mod_test/mod_test/1896.jpg
#   inflating: /data/mod_test/mod_test/1897.jpg
#   inflating: /data/mod_test/mod_test/1898.jpg
#   inflating: /data/mod_test/mod_test/1899.jpg
#   inflating: /data/mod_test/mod_test/1900.jpg
#   inflating: /data/mod_test/mod_test/1901.jpg
#   inflating: /data/mod_test/mod_test/1902.jpg
#   inflating: /data/mod_test/mod_test/1903.jpg
#   inflating: /data/mod_test/mod_test/1904.jpg
#   inflating: /data/mod_test/mod_test/1905.jpg
#   inflating: /data/mod_test/mod_test/1906.jpg
#   inflating: /data/mod_test/mod_test/1907.jpg
#   inflating: /data/mod_test/mod_test/1908.jpg
#   inflating: /data/mod_test/mod_test/1909.jpg
#   inflating: /data/mod_test/mod_test/1910.jpg
#   inflating: /data/mod_test/mod_test/1911.jpg
#   inflating: /data/mod_test/mod_test/1912.jpg
#   inflating: /data/mod_test/mod_test/1913.jpg
#   inflating: /data/mod_test/mod_test/1914.jpg
#   inflating: /data/mod_test/mod_test/1915.jpg
#   inflating: /data/mod_test/mod_test/1916.jpg
#   inflating: /data/mod_test/mod_test/1917.jpg
#   inflating: /data/mod_test/mod_test/1918.jpg
#   inflating: /data/mod_test/mod_test/1919.jpg
#   inflating: /data/mod_test/mod_test/1920.jpg
#   inflating: /data/mod_test/mod_test/1921.jpg
#   inflating: /data/mod_test/mod_test/1922.jpg
#   inflating: /data/mod_test/mod_test/1923.jpg
#   inflating: /data/mod_test/mod_test/1924.jpg
#   inflating: /data/mod_test/mod_test/1925.jpg
#   inflating: /data/mod_test/mod_test/1926.jpg
#   inflating: /data/mod_test/mod_test/1927.jpg
#   inflating: /data/mod_test/mod_test/1928.jpg
#   inflating: /data/mod_test/mod_test/1929.jpg
#   inflating: /data/mod_test/mod_test/1930.jpg
#   inflating: /data/mod_test/mod_test/1931.jpg
#   inflating: /data/mod_test/mod_test/1932.jpg
#   inflating: /data/mod_test/mod_test/1933.jpg
#   inflating: /data/mod_test/mod_test/1934.jpg
#   inflating: /data/mod_test/mod_test/1935.jpg
#   inflating: /data/mod_test/mod_test/1936.jpg
#   inflating: /data/mod_test/mod_test/1937.jpg
#   inflating: /data/mod_test/mod_test/1938.jpg
#   inflating: /data/mod_test/mod_test/1939.jpg
#   inflating: /data/mod_test/mod_test/1940.jpg
#   inflating: /data/mod_test/mod_test/1941.jpg
#   inflating: /data/mod_test/mod_test/1942.jpg
#   inflating: /data/mod_test/mod_test/1943.jpg
#   inflating: /data/mod_test/mod_test/1944.jpg
#   inflating: /data/mod_test/mod_test/1945.jpg
#   inflating: /data/mod_test/mod_test/1946.jpg
#   inflating: /data/mod_test/mod_test/1947.jpg
#   inflating: /data/mod_test/mod_test/1948.jpg
#   inflating: /data/mod_test/mod_test/1949.jpg
#   inflating: /data/mod_test/mod_test/1950.jpg
#   inflating: /data/mod_test/mod_test/1951.jpg
#   inflating: /data/mod_test/mod_test/1952.jpg
#   inflating: /data/mod_test/mod_test/1953.jpg
#   inflating: /data/mod_test/mod_test/1954.jpg
#   inflating: /data/mod_test/mod_test/1955.jpg
#   inflating: /data/mod_test/mod_test/1956.jpg
#   inflating: /data/mod_test/mod_test/1957.jpg
#   inflating: /data/mod_test/mod_test/1958.jpg
#   inflating: /data/mod_test/mod_test/1959.jpg
#   inflating: /data/mod_test/mod_test/1960.jpg
#   inflating: /data/mod_test/mod_test/1961.jpg
#   inflating: /data/mod_test/mod_test/1962.jpg
#   inflating: /data/mod_test/mod_test/1963.jpg
#   inflating: /data/mod_test/mod_test/1964.jpg
#   inflating: /data/mod_test/mod_test/1965.jpg
#   inflating: /data/mod_test/mod_test/1966.jpg
#   inflating: /data/mod_test/mod_test/1967.jpg
#   inflating: /data/mod_test/mod_test/1968.jpg
#   inflating: /data/mod_test/mod_test/1969.jpg
#   inflating: /data/mod_test/mod_test/1970.jpg
#   inflating: /data/mod_test/mod_test/1971.jpg
#   inflating: /data/mod_test/mod_test/1972.jpg
#   inflating: /data/mod_test/mod_test/1973.jpg
#   inflating: /data/mod_test/mod_test/1974.jpg
#   inflating: /data/mod_test/mod_test/1975.jpg
#   inflating: /data/mod_test/mod_test/1976.jpg
#   inflating: /data/mod_test/mod_test/1977.jpg
#   inflating: /data/mod_test/mod_test/1978.jpg
#   inflating: /data/mod_test/mod_test/1979.jpg
#   inflating: /data/mod_test/mod_test/1980.jpg
#   inflating: /data/mod_test/mod_test/1981.jpg
#   inflating: /data/mod_test/mod_test/1982.jpg
#   inflating: /data/mod_test/mod_test/1983.jpg
#   inflating: /data/mod_test/mod_test/1984.jpg
#   inflating: /data/mod_test/mod_test/1985.jpg
#   inflating: /data/mod_test/mod_test/1986.jpg
#   inflating: /data/mod_test/mod_test/1987.jpg
#   inflating: /data/mod_test/mod_test/1988.jpg
#   inflating: /data/mod_test/mod_test/1989.jpg
#   inflating: /data/mod_test/mod_test/1990.jpg
#   inflating: /data/mod_test/mod_test/1991.jpg
#   inflating: /data/mod_test/mod_test/1992.jpg
#   inflating: /data/mod_test/mod_test/1993.jpg
#   inflating: /data/mod_test/mod_test/1994.jpg
#   inflating: /data/mod_test/mod_test/1995.jpg
#   inflating: /data/mod_test/mod_test/1996.jpg
#   inflating: /data/mod_test/mod_test/1997.jpg
#   inflating: /data/mod_test/mod_test/1998.jpg
#   inflating: /data/mod_test/mod_test/1999.jpg
#   inflating: /data/mod_test/mod_test/2000.jpg
#   inflating: /data/mod_test/mod_test/2001.jpg
#   inflating: /data/mod_test/mod_test/2002.jpg
#   inflating: /data/mod_test/mod_test/2003.jpg
#   inflating: /data/mod_test/mod_test/2004.jpg
#   inflating: /data/mod_test/mod_test/2005.jpg
#   inflating: /data/mod_test/mod_test/2006.jpg
#   inflating: /data/mod_test/mod_test/2007.jpg
#   inflating: /data/mod_test/mod_test/2008.jpg
#   inflating: /data/mod_test/mod_test/2009.jpg
#   inflating: /data/mod_test/mod_test/2010.jpg
#   inflating: /data/mod_test/mod_test/2011.jpg
#   inflating: /data/mod_test/mod_test/2012.jpg
#   inflating: /data/mod_test/mod_test/2013.jpg
#   inflating: /data/mod_test/mod_test/2014.jpg
#   inflating: /data/mod_test/mod_test/2015.jpg
#   inflating: /data/mod_test/mod_test/2016.jpg
#   inflating: /data/mod_test/mod_test/2017.jpg
#   inflating: /data/mod_test/mod_test/2018.jpg
#   inflating: /data/mod_test/mod_test/2019.jpg
#   inflating: /data/mod_test/mod_test/2020.jpg
#   inflating: /data/mod_test/mod_test/2021.jpg
#   inflating: /data/mod_test/mod_test/2022.jpg
#   inflating: /data/mod_test/mod_test/2023.jpg
#   inflating: /data/mod_test/mod_test/2024.jpg
#   inflating: /data/mod_test/mod_test/2025.jpg
#   inflating: /data/mod_test/mod_test/2026.jpg
#   inflating: /data/mod_test/mod_test/2027.jpg
#   inflating: /data/mod_test/mod_test/2028.jpg
#   inflating: /data/mod_test/mod_test/2029.jpg
#   inflating: /data/mod_test/mod_test/2030.jpg
# ...
#   inflating: /data/validation/validation/148.Green_tailed_Towhee/Green_tailed_Towhee_0021_149577903.jpg
#   inflating: /data/validation/validation/149.Brown_Thrasher/Brown_Thrasher_0009_251469850.jpg
#   inflating: /data/validation/validation/149.Brown_Thrasher/Brown_Thrasher_0019_172583186.jpg
#   inflating: /data/validation/validation/149.Brown_Thrasher/Brown_Thrasher_0028_176724840.jpg
#   inflating: /data/validation/validation/150.Sage_Thrasher/Sage_Thrasher_0005_133924622.jpg
#   inflating: /data/validation/validation/150.Sage_Thrasher/Sage_Thrasher_0009_2616266535.jpg
#   inflating: /data/validation/validation/150.Sage_Thrasher/Sage_Thrasher_0022_459478483.jpg
#   inflating: /data/validation/validation/151.Black_capped_Vireo/Black_capped_Vireo_0001_xxx.jpg
#   inflating: /data/validation/validation/151.Black_capped_Vireo/Black_capped_Vireo_0004_467561522.jpg
#   inflating: /data/validation/validation/151.Black_capped_Vireo/Black_capped_Vireo_0010_238846344.jpg
#   inflating: /data/validation/validation/152.Blue_headed_Vireo/Blue_headed_Vireo_0004_261315463.jpg
#   inflating: /data/validation/validation/152.Blue_headed_Vireo/Blue_headed_Vireo_0009_2484454863.jpg
#   inflating: /data/validation/validation/152.Blue_headed_Vireo/Blue_headed_Vireo_0010_85053176.jpg
#   inflating: /data/validation/validation/153.Philadelphia_Vireo/Philadelphia_Vireo_0021_59213650.jpg
#   inflating: /data/validation/validation/153.Philadelphia_Vireo/Philadelphia_Vireo_0031_2969853985.jpg
#   inflating: /data/validation/validation/153.Philadelphia_Vireo/Philadelphia_Vireo_0034_239356970.jpg
#   inflating: /data/validation/validation/154.Red_eyed_Vireo/Red_eyed_Vireo_0010_2224604942.jpg
#   inflating: /data/validation/validation/154.Red_eyed_Vireo/Red_eyed_Vireo_0029_59210443.jpg
#   inflating: /data/validation/validation/154.Red_eyed_Vireo/Red_eyed_Vireo_0033_2495509969.jpg
#   inflating: /data/validation/validation/155.Warbling_Vireo/Warbling_Vireo_0020_2081455009.jpg
#   inflating: /data/validation/validation/155.Warbling_Vireo/Warbling_Vireo_0032_204363633.jpg
#   inflating: /data/validation/validation/155.Warbling_Vireo/Warbling_Vireo_0034_455463333.jpg
#   inflating: /data/validation/validation/156.White_eyed_Vireo/White_eyed_Vireo_0019_156824638.jpg
#   inflating: /data/validation/validation/156.White_eyed_Vireo/White_eyed_Vireo_0020_3083009361.jpg
#   inflating: /data/validation/validation/156.White_eyed_Vireo/White_eyed_Vireo_0027_480407852.jpg
#   inflating: /data/validation/validation/157.Yellow_throated_Vireo/Yellow_throated_Vireo_0003_59209019.jpg
#   inflating: /data/validation/validation/157.Yellow_throated_Vireo/Yellow_throated_Vireo_0007_147252880.jpg
#   inflating: /data/validation/validation/157.Yellow_throated_Vireo/Yellow_throated_Vireo_0030_134378733.jpg
#   inflating: /data/validation/validation/158.Bay_breasted_Warbler/Bay_breasted_Warbler_0004_496025312.jpg
#   inflating: /data/validation/validation/158.Bay_breasted_Warbler/Bay_breasted_Warbler_0018_500314630.jpg
#   inflating: /data/validation/validation/158.Bay_breasted_Warbler/Bay_breasted_Warbler_0025_211976112.jpg
#   inflating: /data/validation/validation/159.Black_and_white_Warbler/Black_and_white_Warbler_0002_1562071549.jpg
#   inflating: /data/validation/validation/159.Black_and_white_Warbler/Black_and_white_Warbler_0008_29497275.jpg
#   inflating: /data/validation/validation/159.Black_and_white_Warbler/Black_and_white_Warbler_0023_532383478.jpg
#   inflating: /data/validation/validation/160.Black_throated_Blue_Warbler/Black_throated_Blue_Warbler_0011_2880014334.jpg
#   inflating: /data/validation/validation/160.Black_throated_Blue_Warbler/Black_throated_Blue_Warbler_0012_2917543822.jpg
#   inflating: /data/validation/validation/160.Black_throated_Blue_Warbler/Black_throated_Blue_Warbler_0013_190366889.jpg
#   inflating: /data/validation/validation/161.Blue_winged_Warbler/Blue_winged_Warbler_0016_493024382.jpg
#   inflating: /data/validation/validation/161.Blue_winged_Warbler/Blue_winged_Warbler_0022_494751942.jpg
#   inflating: /data/validation/validation/161.Blue_winged_Warbler/Blue_winged_Warbler_0031_1989197116.jpg
#   inflating: /data/validation/validation/162.Canada_Warbler/Canada_Warbler_0011_xxx.jpg
#   inflating: /data/validation/validation/162.Canada_Warbler/Canada_Warbler_0022_538698268.jpg
#   inflating: /data/validation/validation/162.Canada_Warbler/Canada_Warbler_0033_689000063.jpg
#   inflating: /data/validation/validation/163.Cape_May_Warbler/Cape_May_Warbler_0003_24833741.jpg
#   inflating: /data/validation/validation/163.Cape_May_Warbler/Cape_May_Warbler_0024_150760578.jpg
#   inflating: /data/validation/validation/163.Cape_May_Warbler/Cape_May_Warbler_0027_xxx.jpg
#   inflating: /data/validation/validation/164.Cerulean_Warbler/Cerulean_Warbler_0009_906444639.jpg
#   inflating: /data/validation/validation/164.Cerulean_Warbler/Cerulean_Warbler_0011_69462946.jpg
#   inflating: /data/validation/validation/164.Cerulean_Warbler/Cerulean_Warbler_0019_xxx.jpg
#   inflating: /data/validation/validation/165.Chestnut_sided_Warbler/Chestnut_sided_Warbler_0003_29499504.jpg
#   inflating: /data/validation/validation/165.Chestnut_sided_Warbler/Chestnut_sided_Warbler_0018_1755798667.jpg
#   inflating: /data/validation/validation/165.Chestnut_sided_Warbler/Chestnut_sided_Warbler_0027_497237807.jpg
#   inflating: /data/validation/validation/166.Golden_winged_Warbler/Golden_winged_Warbler_0001_495149583.jpg
#   inflating: /data/validation/validation/166.Golden_winged_Warbler/Golden_winged_Warbler_0030_520345206.jpg
#   inflating: /data/validation/validation/166.Golden_winged_Warbler/Golden_winged_Warbler_0034_1347737145.jpg
#   inflating: /data/validation/validation/167.Hooded_Warbler/Hooded_Warbler_0009_67483709.jpg
#   inflating: /data/validation/validation/167.Hooded_Warbler/Hooded_Warbler_0010_53159577.jpg
#   inflating: /data/validation/validation/167.Hooded_Warbler/Hooded_Warbler_0011_1472759322.jpg
#   inflating: /data/validation/validation/168.Kentucky_Warbler/Kentucky_Warbler_0016_162158976.jpg
#   inflating: /data/validation/validation/168.Kentucky_Warbler/Kentucky_Warbler_0017_154170680.jpg
#   inflating: /data/validation/validation/168.Kentucky_Warbler/Kentucky_Warbler_0018_xxx.jpg
#   inflating: /data/validation/validation/169.Magnolia_Warbler/Magnolia_Warbler_0008_xxx.jpg
#   inflating: /data/validation/validation/169.Magnolia_Warbler/Magnolia_Warbler_0013_527519472.jpg
#   inflating: /data/validation/validation/169.Magnolia_Warbler/Magnolia_Warbler_0022_xxx.jpg
#   inflating: /data/validation/validation/170.Mourning_Warbler/Mourning_Warbler_0015_2518496557.jpg
#   inflating: /data/validation/validation/170.Mourning_Warbler/Mourning_Warbler_0018_392495285.jpg
#   inflating: /data/validation/validation/170.Mourning_Warbler/Mourning_Warbler_0023_343485567.jpg
#   inflating: /data/validation/validation/171.Myrtle_Warbler/Myrtle_Warbler_0003_1527801198.jpg
#   inflating: /data/validation/validation/171.Myrtle_Warbler/Myrtle_Warbler_0009_xxx.jpg
#   inflating: /data/validation/validation/171.Myrtle_Warbler/Myrtle_Warbler_0010_2349521187.jpg
#   inflating: /data/validation/validation/172.Nashville_Warbler/Nashville_Warbler_0013_2910087389.jpg
#   inflating: /data/validation/validation/172.Nashville_Warbler/Nashville_Warbler_0021_267795978.jpg
#   inflating: /data/validation/validation/172.Nashville_Warbler/Nashville_Warbler_0023_150433556.jpg
#   inflating: /data/validation/validation/173.Orange_crowned_Warbler/Orange_crowned_Warbler_0008_2405790599.jpg
#   inflating: /data/validation/validation/173.Orange_crowned_Warbler/Orange_crowned_Warbler_0011_125433265.jpg
#   inflating: /data/validation/validation/173.Orange_crowned_Warbler/Orange_crowned_Warbler_0020_1216180087.jpg
#   inflating: /data/validation/validation/174.Palm_Warbler/Palm_Warbler_0015_2267395393.jpg
#   inflating: /data/validation/validation/174.Palm_Warbler/Palm_Warbler_0022_276178395.jpg
#   inflating: /data/validation/validation/174.Palm_Warbler/Palm_Warbler_0028_2411273555.jpg
#   inflating: /data/validation/validation/175.Pine_Warbler/Pine_Warbler_0007_454566850.jpg
#   inflating: /data/validation/validation/175.Pine_Warbler/Pine_Warbler_0027_72255573.jpg
#   inflating: /data/validation/validation/175.Pine_Warbler/Pine_Warbler_0029_435738167.jpg
#   inflating: /data/validation/validation/176.Prairie_Warbler/Prairie_Warbler_0006_287222067.jpg
#   inflating: /data/validation/validation/176.Prairie_Warbler/Prairie_Warbler_0025_480010585.jpg
#   inflating: /data/validation/validation/176.Prairie_Warbler/Prairie_Warbler_0032_2490198426.jpg
#   inflating: /data/validation/validation/177.Prothonotary_Warbler/Prothonotary_Warbler_0007_504305546.jpg
#   inflating: /data/validation/validation/177.Prothonotary_Warbler/Prothonotary_Warbler_0029_480952118.jpg
#   inflating: /data/validation/validation/177.Prothonotary_Warbler/Prothonotary_Warbler_0030_2468915211.jpg
#   inflating: /data/validation/validation/178.Swainson_Warbler/Swainson_Warbler_0011_520143156.jpg
#   inflating: /data/validation/validation/178.Swainson_Warbler/Swainson_Warbler_0019_2311786618.jpg
#   inflating: /data/validation/validation/178.Swainson_Warbler/Swainson_Warbler_0024_1208631223.jpg
#   inflating: /data/validation/validation/179.Tennessee_Warbler/Tennessee_Warbler_0009_59210443.jpg
#   inflating: /data/validation/validation/179.Tennessee_Warbler/Tennessee_Warbler_0020_59210520.jpg
#   inflating: /data/validation/validation/179.Tennessee_Warbler/Tennessee_Warbler_0027_1389747854.jpg
#   inflating: /data/validation/validation/180.Wilson_Warbler/Wilson_Warbler_0010_59210327.jpg
#   inflating: /data/validation/validation/180.Wilson_Warbler/Wilson_Warbler_0017_151557914.jpg
#   inflating: /data/validation/validation/180.Wilson_Warbler/Wilson_Warbler_0030_156829250.jpg
#   inflating: /data/validation/validation/181.Worm_eating_Warbler/Worm_eating_Warbler_0009_2661303277.jpg
#   inflating: /data/validation/validation/181.Worm_eating_Warbler/Worm_eating_Warbler_0014_1344001975.jpg
#   inflating: /data/validation/validation/181.Worm_eating_Warbler/Worm_eating_Warbler_0024_2701320621.jpg
#   inflating: /data/validation/validation/182.Yellow_Warbler/Yellow_Warbler_0002_683648294.jpg
#   inflating: /data/validation/validation/182.Yellow_Warbler/Yellow_Warbler_0006_515492732.jpg
#   inflating: /data/validation/validation/182.Yellow_Warbler/Yellow_Warbler_0013_147191373.jpg
#   inflating: /data/validation/validation/183.Northern_Waterthrush/Northern_Waterthrush_0009_59213174.jpg
#   inflating: /data/validation/validation/183.Northern_Waterthrush/Northern_Waterthrush_0028_155580940.jpg
#   inflating: /data/validation/validation/183.Northern_Waterthrush/Northern_Waterthrush_0035_150804698.jpg
#   inflating: /data/validation/validation/184.Louisiana_Waterthrush/Louisiana_Waterthrush_0006_521585162.jpg
#   inflating: /data/validation/validation/184.Louisiana_Waterthrush/Louisiana_Waterthrush_0021_528326647.jpg
#   inflating: /data/validation/validation/184.Louisiana_Waterthrush/Louisiana_Waterthrush_0024_10442225.jpg
#   inflating: /data/validation/validation/185.Bohemian_Waxwing/Bohemian_Waxwing_0001_2233840010.jpg
#   inflating: /data/validation/validation/185.Bohemian_Waxwing/Bohemian_Waxwing_0015_830047485.jpg
#   inflating: /data/validation/validation/185.Bohemian_Waxwing/Bohemian_Waxwing_0018_2147785420.jpg
#   inflating: /data/validation/validation/186.Cedar_Waxwing/Cedar_Waxwing_0002_380004531.jpg
#   inflating: /data/validation/validation/186.Cedar_Waxwing/Cedar_Waxwing_0010_81998414.jpg
#   inflating: /data/validation/validation/186.Cedar_Waxwing/Cedar_Waxwing_0023_392397088.jpg
#   inflating: /data/validation/validation/187.American_Three_toed_Woodpecker/American_Three_toed_Woodpecker_0004_340037745.jpg
#   inflating: /data/validation/validation/187.American_Three_toed_Woodpecker/American_Three_toed_Woodpecker_0012_171736741.jpg
#   inflating: /data/validation/validation/187.American_Three_toed_Woodpecker/American_Three_toed_Woodpecker_0016_2250022414.jpg
#   inflating: /data/validation/validation/188.Pileated_Woodpecker/Pileated_Woodpecker_0012_541439754.jpg
#   inflating: /data/validation/validation/188.Pileated_Woodpecker/Pileated_Woodpecker_0021_25993105.jpg
#   inflating: /data/validation/validation/188.Pileated_Woodpecker/Pileated_Woodpecker_0036_25993104.jpg
#   inflating: /data/validation/validation/189.Red_bellied_Woodpecker/Red_bellied_Woodpecker_0010_2198873145.jpg
#   inflating: /data/validation/validation/189.Red_bellied_Woodpecker/Red_bellied_Woodpecker_0015_1452170619.jpg
#   inflating: /data/validation/validation/189.Red_bellied_Woodpecker/Red_bellied_Woodpecker_0019_143774989.jpg
#   inflating: /data/validation/validation/190.Red_cockaded_Woodpecker/Red_cockaded_Woodpecker_0008_2626376214.jpg
#   inflating: /data/validation/validation/190.Red_cockaded_Woodpecker/Red_cockaded_Woodpecker_0017_707481249.jpg
#   inflating: /data/validation/validation/190.Red_cockaded_Woodpecker/Red_cockaded_Woodpecker_0021_2341905802.jpg
#   inflating: /data/validation/validation/191.Red_headed_Woodpecker/Red_headed_Woodpecker_0005_2195928350.jpg
#   inflating: /data/validation/validation/191.Red_headed_Woodpecker/Red_headed_Woodpecker_0024_316230604.jpg
#   inflating: /data/validation/validation/191.Red_headed_Woodpecker/Red_headed_Woodpecker_0029_631526205.jpg
#   inflating: /data/validation/validation/192.Downy_Woodpecker/Downy_Woodpecker_0001_7728791.jpg
#   inflating: /data/validation/validation/192.Downy_Woodpecker/Downy_Woodpecker_0013_3881641.jpg
#   inflating: /data/validation/validation/192.Downy_Woodpecker/Downy_Woodpecker_0032_116312748.jpg
#   inflating: /data/validation/validation/193.Bewick_Wren/Bewick_Wren_0002_340170022.jpg
#   inflating: /data/validation/validation/193.Bewick_Wren/Bewick_Wren_0019_305351818.jpg
#   inflating: /data/validation/validation/193.Bewick_Wren/Bewick_Wren_0034_167744800.jpg
#   inflating: /data/validation/validation/194.Cactus_Wren/Cactus_Wren_0009_2056959965.jpg
#   inflating: /data/validation/validation/194.Cactus_Wren/Cactus_Wren_0019_1653250171.jpg
#   inflating: /data/validation/validation/194.Cactus_Wren/Cactus_Wren_0021_1653250197.jpg
#   inflating: /data/validation/validation/195.Carolina_Wren/Carolina_Wren_0001_232802928.jpg
#   inflating: /data/validation/validation/195.Carolina_Wren/Carolina_Wren_0006_2351512377.jpg
#   inflating: /data/validation/validation/195.Carolina_Wren/Carolina_Wren_0032_505240005.jpg
#   inflating: /data/validation/validation/196.House_Wren/House_Wren_0011_2896312595.jpg
#   inflating: /data/validation/validation/196.House_Wren/House_Wren_0015_142884140.jpg
#   inflating: /data/validation/validation/196.House_Wren/House_Wren_0016_172312721.jpg
#   inflating: /data/validation/validation/197.Marsh_Wren/Marsh_Wren_0021_2068994678.jpg
#   inflating: /data/validation/validation/197.Marsh_Wren/Marsh_Wren_0026_53824752.jpg
#   inflating: /data/validation/validation/197.Marsh_Wren/Marsh_Wren_0032_887281664.jpg
#   inflating: /data/validation/validation/198.Rock_Wren/Rock_Wren_0014_2487623.jpg
#   inflating: /data/validation/validation/198.Rock_Wren/Rock_Wren_0023_291147322.jpg
#   inflating: /data/validation/validation/198.Rock_Wren/Rock_Wren_0025_2538963798.jpg
#   inflating: /data/validation/validation/199.Winter_Wren/Winter_Wren_0002_2403527808.jpg
#   inflating: /data/validation/validation/199.Winter_Wren/Winter_Wren_0004_2979975215.jpg
#   inflating: /data/validation/validation/199.Winter_Wren/Winter_Wren_0035_1510546070.jpg
#   inflating: /data/validation/validation/200.Common_Yellowthroat/Common_Yellowthroat_0009_2099303008.jpg
#   inflating: /data/validation/validation/200.Common_Yellowthroat/Common_Yellowthroat_0019_365201869.jpg
#   inflating: /data/validation/validation/200.Common_Yellowthroat/Common_Yellowthroat_0021_189744224.jpg

# %%
ls /data
# Out:
# cifar100/                    cs-543-mp4-fall-2021-p2.zip  new_train/
# cs-543-mp4-fall-2021-p1.zip  mod_test/                    validation/

# %% [markdown]
# # Set up GPU and PyTorch
#
# First, ensure that your notebook on Colaboratory is set up to use GPU. After opening the notebook on Colaboratory, go to Edit>Notebook settings, select Python 3 under "Runtime type," select GPU under "Hardware accelerator," and save.
#
# Next, install PyTorch:

# %%
# !pip3 install torch torchvision
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.11.1+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.10.0.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.19.5)

# %% [markdown]
# Make sure that pytorch is installed and works with GPU:

# %%
import torch
a = torch.Tensor([1]).cuda()
print(a)
# Out:
# tensor([1.], device='cuda:0')

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# # Part 1

# %%
"""Headers"""

from __future__ import print_function
from PIL import Image
import os
import os.path
import numpy as np
import sys
if sys.version_info[0] == 2:
    import cPickle as pickle
else:
    import pickle

import torch.utils.data as data
from torchvision.datasets.utils import download_url, check_integrity
from torchsummary import summary

from sklearn.metrics import confusion_matrix

import csv
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os.path
import sys
import torch
import torch.utils.data
import torchvision
import torchvision.transforms as transforms

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

np.random.seed(111)
torch.cuda.manual_seed_all(111)
torch.manual_seed(111)

# %% [markdown]
# ## **Just execute the cell below. This is the dataloader. DO NOT CHANGE ANYTHING IN HERE!**

# %%
""""""

class CIFAR10_CS543(data.Dataset):
    """`CIFAR10 <https://www.cs.toronto.edu/~kriz/cifar.html>`_ Dataset.

    Args:
        root (string): Root directory of dataset where directory
            ``cifar-10-batches-py`` exists or will be saved to if download is set to True.
        train (bool, optional): If True, creates dataset from training set, otherwise
            creates from test set.
        transform (callable, optional): A function/transform that  takes in an PIL image
            and returns a transformed version. E.g, ``transforms.RandomCrop``
        target_transform (callable, optional): A function/transform that takes in the
            target and transforms it.
        download (bool, optional): If true, downloads the dataset from the internet and
            puts it in root directory. If dataset is already downloaded, it is not
            downloaded again.

    """
    base_folder = 'cifar100'
    url = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
    filename = "cifar100.tar.gz"
    tgz_md5 = 'c58f30108f718f92721af3b95e74349a'
    train_list = [
        ['data_batch_1', 'c99cafc152244af753f735de768cd75f'],
        ['data_batch_2', 'd4bba439e000b95fd0a9bffe97cbabec'],
        ['data_batch_3', '54ebc095f3ab1f0389bbae665268c751'],
        ['data_batch_4', '634d18415352ddfa80567beed471001a'],
        ['data_batch_5', '482c414d41f54cd18b22e5b47cb7c3cb'],
    ]

    test_list = [
        ['test_batch', '40351d587109b95175f43aff81a1287e'],
    ]

    def __init__(self, root, fold="train",
                 transform=None, target_transform=None,
                 download=False):
        
        fold = fold.lower()

        self.train = False
        self.test = False
        self.val = False

        if fold == "train":
            self.train = True
        elif fold == "test":
            self.test = True
        elif fold == "val":
            self.val = True
        else:
            raise RuntimeError("Not train-val-test")


        self.root = os.path.expanduser(root)
        self.transform = transform
        self.target_transform = target_transform

        fpath = os.path.join(root, self.filename)
        if not self._check_integrity():
            raise RuntimeError('Dataset not found or corrupted.' +
                               ' Download it and extract the file again.')

        # now load the picked numpy arrays
        if self.train or self.val:
            self.train_data = []
            self.train_labels = []
            for fentry in self.train_list:
                f = fentry[0]
                file = os.path.join(self.root, self.base_folder, f)
                fo = open(file, 'rb')
                if sys.version_info[0] == 2:
                    entry = pickle.load(fo)
                else:
                    entry = pickle.load(fo, encoding='latin1')
                self.train_data.append(entry['data'])
                if 'labels' in entry:
                    self.train_labels += entry['labels']
                else:
                    self.train_labels += entry['fine_labels']
                fo.close()

            self.train_data = np.concatenate(self.train_data)
            self.train_data = self.train_data.reshape((50000, 3, 32, 32))
            self.train_data = self.train_data.transpose((0, 2, 3, 1))  # convert to HWC
            
            p = np.arange(0,50000,10)
            mask_train = np.ones((50000,), dtype=bool)
            mask_train[p] = False
            mask_val = np.zeros((50000,), dtype=bool)
            mask_val[p] = True

            copy_all_data = np.array(self.train_data)
            self.val_data = np.array(copy_all_data[mask_val])
            self.train_data = np.array(copy_all_data[mask_train])
            
            copy_all_labels = np.array(self.train_labels)
            self.val_labels = np.array(copy_all_labels[mask_val])
            self.train_labels = np.array(copy_all_labels[mask_train])

        elif self.test:
            f = self.test_list[0][0]
            file = os.path.join(self.root, self.base_folder, f)
            fo = open(file, 'rb')
            if sys.version_info[0] == 2:
                entry = pickle.load(fo)
            else:
                entry = pickle.load(fo, encoding='latin1')
            self.test_data = entry['data']

            if 'labels' in entry:
                self.test_labels = entry['labels']
            else:
                self.test_labels = entry['fine_labels']
            fo.close()
            self.test_data = self.test_data.reshape((10000, 3, 32, 32))
            self.test_data = self.test_data.transpose((0, 2, 3, 1))  # convert to HWC

    def __getitem__(self, index):
        """
        Args:
            index (int): Index

        Returns:
            tuple: (image, target) where target is index of the target class.
        """
        if self.train:
            img, target = self.train_data[index], self.train_labels[index]
        elif self.test:
            img, target = self.test_data[index], self.test_labels[index]
        elif self.val:
            img, target = self.val_data[index], self.val_labels[index]

        # doing this so that it is consistent with all other datasets
        # to return a PIL Image
        img = Image.fromarray(img)

        if self.transform is not None:
            img = self.transform(img)

        if self.target_transform is not None:
            target = self.target_transform(target)

        return img, target

    def __len__(self):
        if self.train:
            return len(self.train_data)
        elif self.test:
            return len(self.test_data)
        elif self.val:
            return len(self.val_data)

    def _check_integrity(self):
        root = self.root
        for fentry in (self.train_list + self.test_list):
            filename, md5 = fentry[0], fentry[1]
            fpath = os.path.join(root, self.base_folder, filename)
            if not check_integrity(fpath, md5):
                return False
        return True

    def __repr__(self):
        fmt_str = 'Dataset ' + self.__class__.__name__ + '\n'
        fmt_str += '    Number of datapoints: {}\n'.format(self.__len__())
        tmp = 'train' if self.train is True else 'test'
        fmt_str += '    Split: {}\n'.format(tmp)
        fmt_str += '    Root Location: {}\n'.format(self.root)
        tmp = '    Transforms (if any): '
        fmt_str += '{0}{1}\n'.format(tmp, self.transform.__repr__().replace('\n', '\n' + ' ' * len(tmp)))
        tmp = '    Target Transforms (if any): '
        fmt_str += '{0}{1}'.format(tmp, self.target_transform.__repr__().replace('\n', '\n' + ' ' * len(tmp)))
        return fmt_str


class CIFAR100_CS543(CIFAR10_CS543):
    """`CIFAR100 <https://www.cs.toronto.edu/~kriz/cifar.html>`_ Dataset.

    This is a subclass of the `CIFAR10` Dataset.
    """
    base_folder = 'cifar100'
    filename = "cifar100.tar.gz"
    tgz_md5 = 'e68a4c763591787a0b39fe2209371f32'
    train_list = [
        ['train_cs543', '49eee854445c1e2ebe796cd93c20bb0f'],
    ]

    test_list = [
        ['test_cs543', 'd3fe9f6a9251bd443f428f896d27384f'],
    ]

# %% [markdown]
# This file has been adapted from the easy-to-use tutorial released by PyTorch:
# http://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html
#
# Training an image classifier
# ----------------------------
#
# We will do the following steps in order:
#
# 1. Load the CIFAR100_CS543 training, validation and test datasets using
#    torchvision. Use torchvision.transforms to apply transforms on the
#    dataset.
# 2. Define a Convolution Neural Network - BaseNet
# 3. Define a loss function and optimizer
# 4. Train the network on training data and check performance on val set.
#    Plot train loss and validation accuracies.
# 5. Try the network on test data and create .csv file for submission to kaggle

# %%
# <<TODO#5>> Based on the val set performance, decide how many
# epochs are apt for your model.
# ---------
EPOCHS = 20
# ---------

IS_GPU = True
TEST_BS = 256
TOTAL_CLASSES = 100
TRAIN_BS = 32
PATH_TO_CIFAR100_CS543 = "/data/"

# %%
ls /data/cifar100/
# Out:
# test_cs543  train_cs543

# %%
def calculate_val_accuracy(valloader, is_gpu):
    """ Util function to calculate val set accuracy,
    both overall and per class accuracy
    Args:
        valloader (torch.utils.data.DataLoader): val set 
        is_gpu (bool): whether to run on GPU
    Returns:
        tuple: (overall accuracy, class level accuracy)
    """    
    correct = 0.
    total = 0.
    predictions = []

    class_correct = list(0. for i in range(TOTAL_CLASSES))
    class_total = list(0. for i in range(TOTAL_CLASSES))

    for data in valloader:
        images, labels = data
        if is_gpu:
            images = images.cuda()
            labels = labels.cuda()
        outputs = net(Variable(images))
        _, predicted = torch.max(outputs.data, 1)
        predictions.extend(list(predicted.cpu().numpy()))
        total += labels.size(0)
        correct += (predicted == labels).sum()

        c = (predicted == labels).squeeze()
        for i in range(len(labels)):
            label = labels[i]
            class_correct[label] += c[i]
            class_total[label] += 1

    class_accuracy = 100 * np.divide(class_correct, class_total)
    return 100*correct/total, class_accuracy

# %% [markdown]
# 1.** Loading CIFAR100_CS543**
#
# We modify the dataset to create CIFAR100_CS543 dataset which consist of 45000 training images (450 of each class), 5000 validation images (50 of each class) and 10000 test images (100 of each class). The train and val datasets have labels while all the labels in the test set are set to 0.

# %%
# The output of torchvision datasets are PILImage images of range [0, 1].


# <<TODO#1>> Use transforms.Normalize() with the right parameters to 
# make the data well conditioned (zero mean, std dev=1) for improved training.
# <<TODO#2>> Try using transforms.RandomCrop() and/or transforms.RandomHorizontalFlip()
# to augment training data.
# After your edits, make sure that test_transform should have the same data
# normalization parameters as train_transform
# You shouldn't have any data augmentation in test_transform (val or test data is never augmented).
# ---------------------

train_transform = transforms.Compose(
    [transforms.RandomHorizontalFlip(), 
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
test_transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
# ---------------------

trainset = CIFAR100_CS543(root=PATH_TO_CIFAR100_CS543, fold="train",
                                        download=True, transform=train_transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=TRAIN_BS,
                                          shuffle=True, num_workers=2)
print("Train set size: "+str(len(trainset)))

valset = CIFAR100_CS543(root=PATH_TO_CIFAR100_CS543, fold="val",
                                       download=True, transform=test_transform)
valloader = torch.utils.data.DataLoader(valset, batch_size=TEST_BS,
                                         shuffle=False, num_workers=2)
print("Val set size: "+str(len(valset)))

testset = CIFAR100_CS543(root=PATH_TO_CIFAR100_CS543, fold="test",
                                       download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=TEST_BS,
                                         shuffle=False, num_workers=2)
print("Test set size: "+str(len(testset)))

# The 100 classes for CIFAR100
classes = ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm']
# Out:
# Train set size: 45000
# Val set size: 5000
# Test set size: 10000

# %%
########################################################################
# 2. Define a Convolution Neural Network
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# We provide a basic network that you should understand, run and
# eventually improve
# <<TODO>> Add more conv layers
# <<TODO>> Add more fully connected (fc) layers
# <<TODO>> Add regularization layers like Batchnorm.
#          nn.BatchNorm2d after conv layers:
#          http://pytorch.org/docs/master/nn.html#batchnorm2d
#          nn.BatchNorm1d after fc layers:
#          http://pytorch.org/docs/master/nn.html#batchnorm1d
# This is a good resource for developing a CNN for classification:
# http://cs231n.github.io/convolutional-networks/#layers

import torch.nn as nn
import torch.nn.functional as F

class BaseNet(nn.Module):
    def __init__(self):
        super(BaseNet, self).__init__()
        
        # <<TODO#3>> Add more conv layers with increasing 
        # output channels
        # <<TODO#4>> Add normalization layers after conv
        # layers (nn.BatchNorm2d)

        # Also experiment with kernel size in conv2d layers (say 3
        # inspired from VGGNet)
        # To keep it simple, keep the same kernel size
        # (right now set to 5) in all conv layers.
        # Do not have a maxpool layer after every conv layer in your
        # deeper network as it leads to too much loss of information.
        self.convnet = nn.Sequential(
        nn.Conv2d(3, 16, 3, padding=1),
        nn.BatchNorm2d(16),
        

        nn.Conv2d(16, 32, 3, padding=1),
        nn.BatchNorm2d(32),
        nn.MaxPool2d(2, 2),

        nn.Conv2d(32, 64, 3, padding=1),
        nn.BatchNorm2d(64),
        nn.MaxPool2d(2, 2),
        
        nn.Conv2d(64, 128, 3, padding=1),
        nn.BatchNorm2d(128),
        nn.MaxPool2d(2, 2)
        )

        # <<TODO#3>> Add more linear (fc) layers
        # <<TODO#4>> Add normalization layers after linear and
        # experiment inserting them before or after ReLU (nn.BatchNorm1d)
        # More on nn.sequential:
        # http://pytorch.org/docs/master/nn.html#torch.nn.Sequential
        
        self.fc_net = nn.Sequential(
            nn.Linear(128 * 4 * 4, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(inplace=True),

            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(inplace=True),

            nn.Linear(256, TOTAL_CLASSES//2),
            nn.BatchNorm1d(TOTAL_CLASSES//2),
            nn.ReLU(inplace=True),

            nn.Linear(TOTAL_CLASSES//2, TOTAL_CLASSES),
            nn.BatchNorm1d(TOTAL_CLASSES),
        
        )

    def forward(self, x):

        # <<TODO#3&#4>> Based on the above edits, you'll have
        # to edit the forward pass description here.
        x = self.convnet(x)
        #x = self.pool(F.relu(self.conv1(x)))
        # Output size = 28//2 x 28//2 = 14 x 14
        #x = self.pool(F.relu(self.conv2(x)))
        #x = self.pool(F.relu(self.conv3(x)))
        #x = F.relu(self.conv4(x))
        #x = self.pool(F.relu(self.bnorm1(self.conv2(x))))

        #x = self.pool(F.relu(self.bnorm2(self.conv3(x))))

        # Output size = 10//2 x 10//2 = 5 x 5

        #x = F.relu(self.bnorm3(self.conv4(x)))

        # See the CS231 link to understand why this is 16*5*5!
        # This will help you design your own deeper network
        x = x.view(-1, 128 * 4 * 4)
        x = self.fc_net(x)

        # No softmax is needed as the loss function in step 3
        # takes care of that
        
        return x

# Create an instance of the nn.module class defined above:
net = BaseNet()

# For training on GPU, we need to transfer net and data onto the GPU
# http://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html#training-on-gpu
if IS_GPU:
    net = net.cuda()

# %%
########################################################################
# 3. Define a Loss function and optimizer
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Here we use Cross-Entropy loss and SGD with momentum.
# The CrossEntropyLoss criterion already includes softmax within its
# implementation. That's why we don't use a softmax in our model
# definition.

import torch.optim as optim
criterion = nn.CrossEntropyLoss()

# Tune the learning rate.
# See whether the momentum is useful or not
optimizer = optim.SGD(net.parameters(), lr=0.005, momentum=0.9)

plt.ioff()
fig = plt.figure()
train_loss_over_epochs = []
val_accuracy_over_epochs = []

# %%
########################################################################
# 4. Train the network
# ^^^^^^^^^^^^^^^^^^^^
#
# We simply have to loop over our data iterator, and feed the inputs to the
# network and optimize. We evaluate the validation accuracy at each
# epoch and plot these values over the number of epochs
# Nothing to change here
# -----------------------------
for epoch in range(EPOCHS):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs
        inputs, labels = data

        if IS_GPU:
            inputs = inputs.cuda()
            labels = labels.cuda()

        # wrap them in Variable
        inputs, labels = Variable(inputs), Variable(labels)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
    
    # Normalizing the loss by the total number of train batches
    running_loss/=len(trainloader)
    print('[%d] loss: %.3f' %
          (epoch + 1, running_loss))

    # Scale of 0.0 to 100.0
    # Calculate validation set accuracy of the existing model
    val_accuracy, val_classwise_accuracy = \
        calculate_val_accuracy(valloader, IS_GPU)
    print('Accuracy of the network on the val images: %d %%' % (val_accuracy))

    # # Optionally print classwise accuracies
    # for c_i in range(TOTAL_CLASSES):
    #     print('Accuracy of %5s : %2d %%' % (
    #         classes[c_i], 100 * val_classwise_accuracy[c_i]))

    train_loss_over_epochs.append(running_loss)
    val_accuracy_over_epochs.append(val_accuracy)
# -----------------------------


# Plot train loss over epochs and val set accuracy over epochs
# Nothing to change here
# -------------
plt.subplot(2, 1, 1)
plt.ylabel('Train loss')
plt.plot(np.arange(EPOCHS), train_loss_over_epochs, 'k-')
plt.title('train loss and val accuracy')
plt.xticks(np.arange(EPOCHS, dtype=int))
plt.grid(True)

plt.subplot(2, 1, 2)
plt.plot(np.arange(EPOCHS), val_accuracy_over_epochs, 'b-')
plt.ylabel('Val accuracy')
plt.xlabel('Epochs')
plt.xticks(np.arange(EPOCHS, dtype=int))
plt.grid(True)
plt.savefig("plot.png")
plt.close(fig)
print('Finished Training')
# -------------
# Out:
# [1] loss: 3.661
# Accuracy of the network on the val images: 25 %
# [2] loss: 2.993
# Accuracy of the network on the val images: 33 %
# [3] loss: 2.654
# Accuracy of the network on the val images: 38 %
# [4] loss: 2.433
# Accuracy of the network on the val images: 41 %
# [5] loss: 2.258
# Accuracy of the network on the val images: 43 %
# [6] loss: 2.119
# Accuracy of the network on the val images: 44 %
# [7] loss: 1.995
# Accuracy of the network on the val images: 46 %
# [8] loss: 1.883
# Accuracy of the network on the val images: 46 %
# [9] loss: 1.774
# Accuracy of the network on the val images: 47 %
# [10] loss: 1.677
# Accuracy of the network on the val images: 47 %
# [11] loss: 1.589
# Accuracy of the network on the val images: 47 %
# [12] loss: 1.500
# Accuracy of the network on the val images: 48 %
# [13] loss: 1.411
# Accuracy of the network on the val images: 48 %
# [14] loss: 1.333
# Accuracy of the network on the val images: 49 %
# [15] loss: 1.267
# Accuracy of the network on the val images: 49 %
# [16] loss: 1.186
# Accuracy of the network on the val images: 48 %
# [17] loss: 1.130
# Accuracy of the network on the val images: 48 %
# [18] loss: 1.057
# Accuracy of the network on the val images: 48 %
# [19] loss: 1.013
# Accuracy of the network on the val images: 48 %
# [20] loss: 0.951
# Accuracy of the network on the val images: 49 %
# Finished Training

# %%
########################################################################
# 5. Try the network on test data, and create .csv file
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
########################################################################

# Check out why .eval() is important!
# https://discuss.pytorch.org/t/model-train-and-model-eval-vs-model-and-model-eval/5744/2
net.eval()

total = 0
predictions = []
for data in testloader:
    images, labels = data

    # For training on GPU, we need to transfer net and data onto the GPU
    # http://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html#training-on-gpu
    if IS_GPU:
        images = images.cuda()
        labels = labels.cuda()
    
    outputs = net(Variable(images))
    _, predicted = torch.max(outputs.data, 1)
    predictions.extend(list(predicted.cpu().numpy()))
    total += labels.size(0)

# Replace your netid here
with open('submission_zixinl4_p1.csv', 'w') as csvfile:
    wr = csv.writer(csvfile, quoting=csv.QUOTE_ALL)
    wr.writerow(["Id", "Prediction1"])
    for l_i, label in enumerate(predictions):
        wr.writerow([str(l_i), str(label)])

# %% [markdown]
# # Part 2

# %%
"""Headers"""
import os
import os.path as osp
import time

# %matplotlib inline
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim

from torchvision import datasets

# %% [markdown]
# # Pre-Trained Model
#
# TODO1. Load pretrained resnet model. Experiment with different models.
#
# TODO2: Replace last fc layer
#
# TODO3. Forward pass

# %%
class PreTrainedResNet(nn.Module):
  def __init__(self, num_classes, feature_extracting):
    super(PreTrainedResNet, self).__init__()
    
    #TODO1: Load pre-trained ResNet Model
    self.resnet18 = models.resnet18(pretrained=True)

    #Set gradients to false
    if feature_extracting:
      for param in self.resnet18.parameters():
          param.requires_grad = False
    
    #Replace last fc layer
    num_feats = self.resnet18.fc.in_features
    
    #TODO2: Replace fc layer in resnet to a linear layer of size (num_feats, num_classes)
    self.resnet18.fc = nn.Linear(num_feats, num_classes)

  def forward(self, x):
    #TODO3: Forward pass x through the model
    x = self.resnet18.forward(x)
    return x

# %%
# Nothing to be edited in this cell
def calculate_val_accuracy(valloader, is_gpu):
    """ Util function to calculate val set accuracy,
    both overall and per class accuracy
    Args:
        valloader (torch.utils.data.DataLoader): val set 
        is_gpu (bool): whether to run on GPU
    Returns:
        tuple: (overall accuracy, class level accuracy)
    """    
    model.eval()
  
    validation_acc = 0.0
  
    with torch.no_grad():
        for batch_idx, (images, labels) in enumerate(dataloaders['validation']):
          #move to GPU
          images, labels = images.cuda(), labels.cuda()

          #forward
          outputs = model.forward(images)

          _, preds = torch.max(outputs.data, 1)

          validation_acc += torch.sum(preds == labels).item()

    validation_acc /= (dataset_sizes['validation'])

    return validation_acc

# %% [markdown]
# # Train

# %%
def train(model, optimizer, criterion, epoch, num_epochs):
  model.train()
  epoch_loss = 0.0
  epoch_acc = 0.0
  
  for batch_idx, (images, labels) in enumerate(dataloaders['new_train']):
    #zero the parameter gradients
    optimizer.zero_grad()
    
    #move to GPU
    images, labels = images.cuda(), labels.cuda()
    
    #forward
    outputs = model.forward(images)
    
    loss = criterion(outputs, labels)
    
    _, preds = torch.max(outputs.data, 1)
    
    loss.backward()
    optimizer.step()
    
    epoch_loss += loss.item()
    epoch_acc += torch.sum(preds == labels).item()
    
  epoch_loss /= dataset_sizes['new_train']
  epoch_acc /= dataset_sizes['new_train']
  
  print('Epoch %d/%d Training Loss %.4f Training Accuracy %.4f Validation Accuracy %.4f' % (epoch, num_epochs, epoch_loss, epoch_acc, calculate_val_accuracy(dataloaders['validation'], IS_GPU)))

# %% [markdown]
# # Main
#
# 1. Vary hyperparams based on the performance in validation set.
# 2. Data augmentation

# %%
#TODO: Vary Hyperparams

NUM_EPOCHS = 30
LEARNING_RATE = 0.001 
BATCH_SIZE = 16
RESNET_LAST_ONLY = True #Fine tunes only the last layer. Set to False to fine tune entire network

root_path = '/data/' #If your data is in a different folder, set the path accodordingly

# TODO: Apply appropriate transforms below
# For instance, use a collection of Transforms.RandomResizedCrop() instead of CenterCrop(), RandomRoate(), Horizontal Flip() and/or Transforms.Normalize()

data_transforms = {
    'new_train': transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        
    ]),
    'validation': transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        
    ]),
    'mod_test': transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# loading datasets with PyTorch ImageFolder
image_datasets = {x: datasets.ImageFolder(os.path.join(root_path, x),
                                          data_transforms[x])
                  for x in ['new_train', 'validation', 'mod_test']}

shuffle_datasets = {'new_train':True, 'validation':False, 'mod_test':False}

# defining data loaders to load data using image_datasets and transforms, here we also specify batch size for the mini batch
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=BATCH_SIZE,
                                             shuffle=shuffle_datasets[x], num_workers=4)
              for x in ['new_train', 'validation', 'mod_test']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['new_train', 'validation', 'mod_test']}
class_names = image_datasets['new_train'].classes
print(len(class_names), dataset_sizes)
# Out:
# 200 {'new_train': 2400, 'validation': 600, 'mod_test': 3033}
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
#Initialize the model
model = PreTrainedResNet(len(class_names), RESNET_LAST_ONLY)
model = model.cuda()

#Setting the optimizer and loss criterion
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=0.9)
criterion = nn.CrossEntropyLoss()

#Begin Train
for epoch in range(NUM_EPOCHS):
  train(model, optimizer, criterion, epoch+1, NUM_EPOCHS)
  
print("Finished Training")
print("-"*10)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch 1/30 Training Loss 0.3335 Training Accuracy 0.0088 Validation Accuracy 0.0283
# Epoch 2/30 Training Loss 0.3063 Training Accuracy 0.0587 Validation Accuracy 0.1000
# Epoch 3/30 Training Loss 0.2816 Training Accuracy 0.1542 Validation Accuracy 0.1617
# Epoch 4/30 Training Loss 0.2593 Training Accuracy 0.2529 Validation Accuracy 0.2200

# %% [markdown]
# # Inference on test set and submission to Kaggle

# %%
model.eval()
final_labels = []
ptr = 0
with torch.no_grad():
    for batch_idx, (images, labels) in enumerate(dataloaders['mod_test']):
      #move to GPU
      images = images.cuda()
      #forward
      outputs = model.forward(images)
      _, preds = torch.max(outputs.data, 1)
      final_labels.extend(preds.tolist())
# Insert your netid here
with open('submission_zixinl4_p2.csv', 'w', newline='') as csv_file:  
    writer = csv.writer(csv_file)
    writer.writerow(["Id", "Prediction"])
    for i, pred in enumerate(final_labels):
        writer.writerow([i, pred])

# %% [markdown]
# # Visualizing the model predictions
#
# Only for viusalizing. Nothing to be done here.

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(1)  # pause a bit so that plots are updated
    
def visualize_model(model, num_images=8):
    images_so_far = 0
    fig = plt.figure()

    for batch_idx, (images, labels) in enumerate(dataloaders['mod_test']):
        #move to GPU
        images, labels = images.cuda(), labels.cuda()
        
        outputs = model(images)
        
        _, preds = torch.max(outputs.data, 1)
       

        for j in range(images.size()[0]):
            images_so_far += 1
            ax = plt.subplot(num_images//2, 2, images_so_far)
            ax.axis('off')
            ax.set_title('class: {} predicted: {}'.format(class_names[labels.data[j]], class_names[preds[j]]))

            imshow(images.cpu().data[j])

            if images_so_far == num_images:
                return

# %%
visualize_model(model)
